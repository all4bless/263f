# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output # Only for iPython

# %% [markdown]
# #Helper function

# %%
def crossMat(a):
    """
    Returns the cross product matrix of vector 'a'.

    Parameters:
    a : np.ndarray
        A 3-element array representing a vector.

    Returns:
    A : np.ndarray
        The cross product matrix corresponding to vector 'a'.
    """
    A = np.array([[0, -a[2], a[1]],
                  [a[2], 0, -a[0]],
                  [-a[1], a[0], 0]])

    return A

# %% [markdown]
# #Gradient and Hessian of elastic energies

# %%
def gradEb(xkm1, ykm1, xk, yk, xkp1, ykp1, curvature0, l_k, EI):
    """
    Returns the derivative of bending energy E_k^b with respect to
    x_{k-1}, y_{k-1}, x_k, y_k, x_{k+1}, and y_{k+1}.

    Parameters:
    xkm1, ykm1 : float
        Coordinates of the previous node (x_{k-1}, y_{k-1}).
    xk, yk : float
        Coordinates of the current node (x_k, y_k).
    xkp1, ykp1 : float
        Coordinates of the next node (x_{k+1}, y_{k+1}).
    curvature0 : float
        Discrete natural curvature at node (xk, yk).
    l_k : float
        Voronoi length of node (xk, yk).
    EI : float
        Bending stiffness.

    Returns:
    dF : np.ndarray
        Derivative of bending energy.
    """

    # Nodes in 3D
    node0 = np.array([xkm1, ykm1, 0.0])
    node1 = np.array([xk, yk, 0])
    node2 = np.array([xkp1, ykp1, 0])

    # Unit vectors along z-axis
    m2e = np.array([0, 0, 1])
    m2f = np.array([0, 0, 1])

    kappaBar = curvature0

    # Initialize gradient of curvature
    gradKappa = np.zeros(6)

    # Edge vectors
    ee = node1 - node0
    ef = node2 - node1

    # Norms of edge vectors
    norm_e = np.linalg.norm(ee)
    norm_f = np.linalg.norm(ef)

    # Unit tangents
    te = ee / norm_e
    tf = ef / norm_f

    # Curvature binormal
    kb = 2.0 * np.cross(te, tf) / (1.0 + np.dot(te, tf))

    chi = 1.0 + np.dot(te, tf)
    tilde_t = (te + tf) / chi
    tilde_d2 = (m2e + m2f) / chi

    # Curvature
    kappa1 = kb[2]

    # Gradient of kappa1 with respect to edge vectors
    Dkappa1De = 1.0 / norm_e * (-kappa1 * tilde_t + np.cross(tf, tilde_d2))
    Dkappa1Df = 1.0 / norm_f * (-kappa1 * tilde_t - np.cross(te, tilde_d2))

    # Populate the gradient of kappa
    gradKappa[0:2] = -Dkappa1De[0:2]
    gradKappa[2:4] = Dkappa1De[0:2] - Dkappa1Df[0:2]
    gradKappa[4:6] = Dkappa1Df[0:2]

    # Gradient of bending energy
    dkappa = kappa1 - kappaBar
    dF = gradKappa * EI * dkappa / l_k

    return dF

# %%
def hessEb(xkm1, ykm1, xk, yk, xkp1, ykp1, curvature0, l_k, EI):
    """
    Returns the Hessian (second derivative) of bending energy E_k^b
    with respect to x_{k-1}, y_{k-1}, x_k, y_k, x_{k+1}, and y_{k+1}.

    Parameters:
    xkm1, ykm1 : float
        Coordinates of the previous node (x_{k-1}, y_{k-1}).
    xk, yk : float
        Coordinates of the current node (x_k, y_k).
    xkp1, ykp1 : float
        Coordinates of the next node (x_{k+1}, y_{k+1}).
    curvature0 : float
        Discrete natural curvature at node (xk, yk).
    l_k : float
        Voronoi length of node (xk, yk).
    EI : float
        Bending stiffness.

    Returns:
    dJ : np.ndarray
        Hessian of bending energy.
    """

    # Nodes in 3D
    node0 = np.array([xkm1, ykm1, 0])
    node1 = np.array([xk, yk, 0])
    node2 = np.array([xkp1, ykp1, 0])

    # Unit vectors along z-axis
    m2e = np.array([0, 0, 1])
    m2f = np.array([0, 0, 1])

    kappaBar = curvature0

    # Initialize gradient of curvature
    gradKappa = np.zeros(6)

    # Edge vectors
    ee = node1 - node0
    ef = node2 - node1

    # Norms of edge vectors
    norm_e = np.linalg.norm(ee)
    norm_f = np.linalg.norm(ef)

    # Unit tangents
    te = ee / norm_e
    tf = ef / norm_f

    # Curvature binormal
    kb = 2.0 * np.cross(te, tf) / (1.0 + np.dot(te, tf))

    chi = 1.0 + np.dot(te, tf)
    tilde_t = (te + tf) / chi
    tilde_d2 = (m2e + m2f) / chi

    # Curvature
    kappa1 = kb[2]

    # Gradient of kappa1 with respect to edge vectors
    Dkappa1De = 1.0 / norm_e * (-kappa1 * tilde_t + np.cross(tf, tilde_d2))
    Dkappa1Df = 1.0 / norm_f * (-kappa1 * tilde_t - np.cross(te, tilde_d2))

    # Populate the gradient of kappa
    gradKappa[0:2] = -Dkappa1De[0:2]
    gradKappa[2:4] = Dkappa1De[0:2] - Dkappa1Df[0:2]
    gradKappa[4:6] = Dkappa1Df[0:2]

    # Compute the Hessian (second derivative of kappa)
    DDkappa1 = np.zeros((6, 6))

    norm2_e = norm_e**2
    norm2_f = norm_f**2

    Id3 = np.eye(3)

    # Helper matrices for second derivatives
    tt_o_tt = np.outer(tilde_t, tilde_t)
    tmp = np.cross(tf, tilde_d2)
    tf_c_d2t_o_tt = np.outer(tmp, tilde_t)
    kb_o_d2e = np.outer(kb, m2e)

    D2kappa1De2 = (2 * kappa1 * tt_o_tt - tf_c_d2t_o_tt - tf_c_d2t_o_tt.T) / norm2_e - \
                  kappa1 / (chi * norm2_e) * (Id3 - np.outer(te, te)) + \
                  (kb_o_d2e + kb_o_d2e.T) / (4 * norm2_e)

    tmp = np.cross(te, tilde_d2)
    te_c_d2t_o_tt = np.outer(tmp, tilde_t)
    tt_o_te_c_d2t = te_c_d2t_o_tt.T
    kb_o_d2f = np.outer(kb, m2f)

    D2kappa1Df2 = (2 * kappa1 * tt_o_tt + te_c_d2t_o_tt + te_c_d2t_o_tt.T) / norm2_f - \
                  kappa1 / (chi * norm2_f) * (Id3 - np.outer(tf, tf)) + \
                  (kb_o_d2f + kb_o_d2f.T) / (4 * norm2_f)
    D2kappa1DeDf = -kappa1 / (chi * norm_e * norm_f) * (Id3 + np.outer(te, tf)) \
                  + 1.0 / (norm_e * norm_f) * (2 * kappa1 * tt_o_tt - tf_c_d2t_o_tt + \
                  tt_o_te_c_d2t - crossMat(tilde_d2))
    D2kappa1DfDe = D2kappa1DeDf.T

    # Populate the Hessian of kappa
    DDkappa1[0:2, 0:2] = D2kappa1De2[0:2, 0:2]
    DDkappa1[0:2, 2:4] = -D2kappa1De2[0:2, 0:2] + D2kappa1DeDf[0:2, 0:2]
    DDkappa1[0:2, 4:6] = -D2kappa1DeDf[0:2, 0:2]
    DDkappa1[2:4, 0:2] = -D2kappa1De2[0:2, 0:2] + D2kappa1DfDe[0:2, 0:2]
    DDkappa1[2:4, 2:4] = D2kappa1De2[0:2, 0:2] - D2kappa1DeDf[0:2, 0:2] - \
                         D2kappa1DfDe[0:2, 0:2] + D2kappa1Df2[0:2, 0:2]
    DDkappa1[2:4, 4:6] = D2kappa1DeDf[0:2, 0:2] - D2kappa1Df2[0:2, 0:2]
    DDkappa1[4:6, 0:2] = -D2kappa1DfDe[0:2, 0:2]
    DDkappa1[4:6, 2:4] = D2kappa1DfDe[0:2, 0:2] - D2kappa1Df2[0:2, 0:2]
    DDkappa1[4:6, 4:6] = D2kappa1Df2[0:2, 0:2]

    # Hessian of bending energy
    dkappa = kappa1 - kappaBar
    dJ = 1.0 / l_k * EI * np.outer(gradKappa, gradKappa)
    dJ += 1.0 / l_k * dkappa * EI * DDkappa1

    return dJ

# %%
def getFb(q, EI, deltaL):
    """
    Compute the bending force and Jacobian of the bending force.

    Parameters:
    q : np.ndarray
        A vector of size 6 containing the coordinates [x_{k-1}, y_{k-1}, x_k, y_k, x_{k+1}, y_{k+1}].
    EI : float
        The bending stiffness.
    deltaL : float
        The Voronoi length.

    Returns:
    Fb : np.ndarray
        Bending force (vector of size 6).
    Jb : np.ndarray
        Jacobian of the bending force (6x6 matrix).
    """

    # Initialize bending force as a zero vector of size 6
    Fb = np.zeros(6)

    # Extract coordinates from q
    xkm1, ykm1, xk, yk, xkp1, ykp1 = q

    # Compute the gradient of bending energy
    gradEnergy = gradEb(xkm1, ykm1, xk, yk, xkp1, ykp1, 0, deltaL, EI)

    # Update bending force
    Fb[0:6] = Fb[0:6] - gradEnergy

    # Initialize Jacobian of bending force as a 6x6 zero matrix
    Jb = np.zeros((6, 6))

    # Compute the Hessian of bending energy
    hessEnergy = hessEb(xkm1, ykm1, xk, yk, xkp1, ykp1, 0, deltaL, EI)

    # Update Jacobian matrix
    Jb[0:6, 0:6] = Jb[0:6, 0:6] - hessEnergy

    return Fb, Jb

# %% [markdown]
# **Test**
#
# The following input and output are known to be correct. The output of gradEb and hessEb should match the ones below.
#
# q = [0.0062 -0.0420 0.0500 -0.0661 0.0938 -0.0420]
#
# EI = 7.8540e-04
#
# deltaL = 0.0500
#
# Fb =
#    -0.2174
#    -0.3948
#     0.0000
#     0.7897
#     0.2174
#    -0.3948
#
#
# Jb =
#
#   -11.2515  -11.4239    7.6162   18.0272    3.6353   -6.6033
#
#   -11.4239   -4.3781    4.8206   16.3724    6.6033  -11.9943
#
#   7.6162    4.8206  -15.2324   -0.0000    7.6162   -4.8206
#
#    18.0272   16.3724   -0.0000  -32.7448  -18.0272   16.3724
#
#    3.6353    6.6033    7.6162  -18.0272  -11.2515   11.4239
#
#    -6.6033  -11.9943   -4.8206   16.3724   11.4239   -4.3781

# %%
# Test
# Function to call getFb with predefined inputs
def test_getFb():
    # Predefined inputs
    q = np.array([0.0062, -0.0420, 0.0500, -0.0661, 0.0938, -0.0420])
    EI = 7.8540e-04
    deltaL = 0.05

    # Call getFb function
    Fb, Jb = getFb(q, EI, deltaL)

    # Print the outputs
    print("Bending Force (Fb):")
    print(Fb)
    print("\nJacobian Matrix (Jb):")
    print(Jb)

# Call the test function
test_getFb()
# Out:
# Bending Force (Fb):
# [-2.17151404e-01 -3.94656909e-01 -9.21181670e-17  7.89313817e-01
#   2.17151404e-01 -3.94656909e-01]
#
# Jacobian Matrix (Jb):
# [[-1.12423262e+01 -1.14216798e+01  7.61126858e+00  1.80208634e+01
#    3.63105763e+00 -6.59918358e+00]
#  [-1.14216798e+01 -4.38226838e+00  4.82249625e+00  1.63758053e+01
#    6.59918358e+00 -1.19935370e+01]
#  [ 7.61126858e+00  4.82249625e+00 -1.52225372e+01  6.77011192e-15
#    7.61126858e+00 -4.82249625e+00]
#  [ 1.80208634e+01  1.63758053e+01  6.77011192e-15 -3.27516107e+01
#   -1.80208634e+01  1.63758053e+01]
#  [ 3.63105763e+00  6.59918358e+00  7.61126858e+00 -1.80208634e+01
#   -1.12423262e+01  1.14216798e+01]
#  [-6.59918358e+00 -1.19935370e+01 -4.82249625e+00  1.63758053e+01
#    1.14216798e+01 -4.38226838e+00]]

# %%
def gradEs(xk, yk, xkp1, ykp1, l_k, EA):
    """
    Calculate the gradient of the stretching energy with respect to the coordinates.

    Args:
    - xk (float): x coordinate of the current point
    - yk (float): y coordinate of the current point
    - xkp1 (float): x coordinate of the next point
    - ykp1 (float): y coordinate of the next point
    - l_k (float): reference length
    - EA (float): elastic modulus

    Returns:
    - F (np.array): Gradient array
    """
    F = np.zeros(4)
    F[0] = -(1.0 - np.sqrt((xkp1 - xk)**2.0 + (ykp1 - yk)**2.0) / l_k) * ((xkp1 - xk)**2.0 + (ykp1 - yk)**2.0)**(-0.5) / l_k * (-2.0 * xkp1 + 2.0 * xk)
    F[1] = -(0.1e1 - np.sqrt((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k) * ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1) / l_k * (-0.2e1 * ykp1 + 0.2e1 * yk)
    F[2] = -(0.1e1 - np.sqrt((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k) * ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1) / l_k * (0.2e1 * xkp1 - 0.2e1 * xk)
    F[3] = -(0.1e1 - np.sqrt((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k) * ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1) / l_k * (0.2e1 * ykp1 - 0.2e1 * yk)

    F = 0.5 * EA * l_k * F  # Scale by EA and l_k

    return F

# %%
import numpy as np

def hessEs(xk, yk, xkp1, ykp1, l_k, EA):
    """
    This function returns the 4x4 Hessian of the stretching energy E_k^s with
    respect to x_k, y_k, x_{k+1}, and y_{k+1}.
    """
    J = np.zeros((4, 4))  # Initialize the Hessian matrix
    J11 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (-2 * xkp1 + 2 * xk) ** 2) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * ((-2 * xkp1 + 2 * xk) ** 2) / 0.2e1 - 0.2e1 * (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1)) / l_k
    J12 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (-2 * ykp1 + 2 * yk) * (-2 * xkp1 + 2 * xk)) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * (-2 * xkp1 + 2 * xk) * (-2 * ykp1 + 2 * yk) / 0.2e1
    J13 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (2 * xkp1 - 2 * xk) * (-2 * xkp1 + 2 * xk)) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * (-2 * xkp1 + 2 * xk) * (2 * xkp1 - 2 * xk) / 0.2e1 + 0.2e1 * (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1)) / l_k
    J14 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (2 * ykp1 - 2 * yk) * (-2 * xkp1 + 2 * xk)) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * (-2 * xkp1 + 2 * xk) * (2 * ykp1 - 2 * yk) / 0.2e1
    J22 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (-2 * ykp1 + 2 * yk) ** 2) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * ((-2 * ykp1 + 2 * yk) ** 2) / 0.2e1 - 0.2e1 * (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1)) / l_k
    J23 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (2 * xkp1 - 2 * xk) * (-2 * ykp1 + 2 * yk)) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * (-2 * ykp1 + 2 * yk) * (2 * xkp1 - 2 * xk) / 0.2e1
    J24 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (2 * ykp1 - 2 * yk) * (-2 * ykp1 + 2 * yk)) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * (-2 * ykp1 + 2 * yk) * (2 * ykp1 - 2 * yk) / 0.2e1 + 0.2e1 * (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1)) / l_k
    J33 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (2 * xkp1 - 2 * xk) ** 2) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * ((2 * xkp1 - 2 * xk) ** 2) / 0.2e1 - 0.2e1 * (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1)) / l_k
    J34 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (2 * ykp1 - 2 * yk) * (2 * xkp1 - 2 * xk)) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * (2 * xkp1 - 2 * xk) * (2 * ykp1 - 2 * yk) / 0.2e1
    J44 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (2 * ykp1 - 2 * yk) ** 2) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * ((2 * ykp1 - 2 * yk) ** 2) / 0.2e1 - 0.2e1 * (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1)) / l_k

    J = np.array([[J11, J12, J13, J14],
                   [J12, J22, J23, J24],
                   [J13, J23, J33, J34],
                   [J14, J24, J34, J44]])

    J *= 0.5 * EA * l_k

    return J

# %%
def getFs(q, EA, deltaL):
    Fs = np.zeros_like(q)  # force
    Js = np.zeros((len(q), len(q)))  # jacobian

    # force due to Es^1
    xkm1 = q[0]
    ykm1 = q[1]
    xk = q[2]
    yk = q[3]
    gradEnergy = gradEs(xkm1, ykm1, xk, yk, deltaL, EA)  # gradEs returns the gradient of (axial stretch)^2
    Fs[0:4] -= gradEnergy

    # Jacobian due to Es^1
    hessEnergy = hessEs(xkm1, ykm1, xk, yk, deltaL, EA)  # hessEs returns the hessian of (axial stretch)^2
    Js[0:4, 0:4] -= hessEnergy

    # force due to Es^2
    xkm1 = q[2]
    ykm1 = q[3]
    xk = q[4]
    yk = q[5]
    gradEnergy = gradEs(xkm1, ykm1, xk, yk, deltaL, EA)  # gradEs returns the gradient of (axial stretch)^2
    Fs[2:6] -= gradEnergy

    # Jacobian due to Es^2
    hessEnergy = hessEs(xkm1, ykm1, xk, yk, deltaL, EA)  # hessEs returns the hessian of (axial stretch)^2
    Js[2:6, 2:6] -= hessEnergy

    return Fs, Js

# %% [markdown]
# **Test for stretching**
#
# The following input and output are known to be correct.
#
# EA = 3.1416e+03
#
# deltaL = 0.05
#
# xk = 0.0062
#
# yk = -0.0420
#
# xkp1 = 0.0500
#
# ykp1 = -0.0661
#
# gradEnergy =
# 0.4129
# -0.2272
# -0.4129
# 0.2272
#
#
# hessEnergy =
#
#    1.0e+04 *
#
#    4.8228   -2.6542   -4.8228    2.6542
#
#    -2.6542    1.4595    2.6542   -1.4595
#
#    -4.8228    2.6542    4.8228   -2.6542
#
#    2.6542   -1.4595   -2.6542    1.4595

# %%
EA = 3.1416e+03
deltaL = 0.05
xk = 0.0062
yk = -0.0420
xkp1 = 0.0500
ykp1 = -0.0661
gradEnergy = gradEs(xk, yk, xkp1, ykp1, deltaL, EA)
hessEnergy = hessEs(xk, yk, xkp1, ykp1, deltaL, EA)
print(gradEnergy)
print(hessEnergy)
# Out:
# [ 0.41289914 -0.2271888  -0.41289914  0.2271888 ]
# [[ 48228.04714612 -26541.62385891 -48228.04714612  26541.62385891]
#  [-26541.62385891  14594.52593277  26541.62385891 -14594.52593277]
#  [-48228.04714612  26541.62385891  48228.04714612 -26541.62385891]
#  [ 26541.62385891 -14594.52593277 -26541.62385891  14594.52593277]]

# %% [markdown]
# #Objective function

# %%
def objfun(q_guess, q_old, u_old, dt, tol, maximum_iter,
           m, mMat,  # inertia
           EI, EA,   # elastic stiffness
           W, C,     # external force
           deltaL):

    q_new = q_guess.copy()

    # Newton-Raphson scheme
    iter_count = 0  # number of iterations
    error = tol * 10  # norm of function value (initialized to a value higher than tolerance)
    flag = 1  # Start with a 'good' simulation (flag=1 means no error)

    while error > tol:
        # Get elastic forces
        Fb, Jb = getFb(q_new, EI, deltaL)
        Fs, Js = getFs(q_new, EA, deltaL)

        # Viscous force
        Fv = -C @ (q_new - q_old) / dt
        Jv = -C / dt

        # Equation of motion
        f = m * (q_new - q_old) / dt**2 - m * u_old / dt - (Fb + Fs + W + Fv)

        # Manipulate the Jacobians
        J = mMat / dt**2 - (Jb + Js + Jv)

        # Newton's update
        q_new = q_new - np.linalg.solve(J, f)

        # Get the norm
        error = np.linalg.norm(f)

        # Update iteration number
        iter_count += 1
        print(f'Iter={iter_count-1}, error={error:.6e}')

        if iter_count > maximum_iter:
            flag = -1  # return with an error signal
            return q_new, flag

    return q_new, flag

# %% [markdown]
# #Main

# %%
import numpy as np

# Inputs (SI units)
# number of vertices
nv = 3

# Time step
dt = 1e-2

# Rod Length
RodLength = 0.10

# Discrete length
deltaL = RodLength / (nv - 1)

# Radius of spheres
R1 = 0.005
R2 = 0.025
R3 = 0.005

# Densities
rho_metal = 7000
rho_gl = 1000
rho = rho_metal - rho_gl

# Cross-sectional radius of rod
r0 = 1e-3

# Young's modulus
Y = 1e9

# Viscosity
visc = 1000.0

# Maximum number of iterations in Newton Solver
maximum_iter = 100

# Total simulation time (it exits after t=totalTime)
totalTime = 10

# Indicate whether images should be saved
saveImage = 0

# How often the plot should be saved?
plotStep = 50

# Utility quantities
ne = nv - 1
EI = Y * np.pi * r0**4 / 4
EA = Y * np.pi * r0**2

# Tolerance on force function
tol = EI / RodLength**2 * 1e-3  # small enough force that can be neglected

# Geometry of the rod
nodes = np.zeros((nv, 2))
for c in range(nv):
    nodes[c, 0] = c * RodLength / ne

# Compute Mass
m = np.zeros(2 * nv)
m[0:2] = 4 / 3 * np.pi * R1**3 * rho_metal
m[2:4] = 4 / 3 * np.pi * R2**3 * rho_metal
m[4:6] = 4 / 3 * np.pi * R3**3 * rho_metal

mMat = np.diag(m)  # Convert into a diagonal matrix

# Gravity
W = np.zeros(2 * nv)
g = np.array([0, -9.8])  # m/s^2 - gravity
W[0:2] = 4 / 3 * np.pi * R1**3 * rho * g
W[2:4] = 4 / 3 * np.pi * R2**3 * rho * g
W[4:6] = 4 / 3 * np.pi * R3**3 * rho * g

# Viscous damping matrix, C
C = np.zeros((2 * nv, 2 * nv))
C1 = 6 * np.pi * visc * R1
C2 = 6 * np.pi * visc * R2
C3 = 6 * np.pi * visc * R3
C[0, 0] = C1
C[1, 1] = C1
C[2, 2] = C2
C[3, 3] = C2
C[4, 4] = C3
C[5, 5] = C3

# Initial conditions
q0 = np.zeros(2 * nv)
for c in range(nv):
    q0[2 * c] = nodes[c, 0]
    q0[2 * c + 1] = nodes[c, 1]

q = q0.copy()
u = (q - q0) / dt

# %%
# Number of time steps
Nsteps = round(totalTime / dt)

ctime = 0

all_pos = np.zeros(Nsteps)
all_v = np.zeros(Nsteps)
midAngle = np.zeros(Nsteps)

for timeStep in range(1, Nsteps):  # Python uses 0-based indexing, hence range starts at 1
    print(f't={ctime:.6f}')

    q, error = objfun(q0, q0, u, dt, tol, maximum_iter, m, mMat, EI, EA, W, C, deltaL)

    if error < 0:
        print('Could not converge. Sorry')
        break  # Exit the loop if convergence fails

    u = (q - q0) / dt  # velocity
    ctime += dt  # current time

    # Update q0
    q0 = q

    """
    if timeStep % plotStep == 0:
      x1 = q[::2]  # Selects every second element starting from index 0
      x2 = q[1::2]  # Selects every second element starting from index 1
      h1 = plt.figure(1)
      plt.clf()  # Clear the current figure
      clear_output(wait=True)  # Clear the previous plot/output: Only for iPython
      plt.plot(x1, x2, 'ko-')  # 'ko-' indicates black color with circle markers and solid lines
      plt.title(f't={ctime:.6f}')  # Format the title with the current time
      plt.axis('equal')  # Set equal scaling
      plt.xlabel('x [m]')
      plt.ylabel('y [m]')
      plt.show()  # Display the figure
    """

    all_pos[timeStep] = q[3]  # Python uses 0-based indexing
    all_v[timeStep] = u[3]

    # Angle at the center
    vec1 = np.array([q[2], q[3], 0]) - np.array([q[0], q[1], 0])
    vec2 = np.array([q[4], q[5], 0]) - np.array([q[2], q[3], 0])
    midAngle[timeStep] = np.degrees(np.arctan2(np.linalg.norm(np.cross(vec1, vec2)), np.dot(vec1, vec2)))

# Plot
plt.figure(2)
t = np.linspace(0, totalTime, Nsteps)
plt.plot(t, all_pos)
plt.xlabel('Time, t [s]')
plt.ylabel('Displacement, $\\delta$ [m]')
plt.savefig('fallingBeam.png')

plt.figure(3)
plt.plot(t, all_v)
plt.xlabel('Time, t [s]')
plt.ylabel('Velocity, v [m/s]')
plt.savefig('fallingBeam_velocity.png')

plt.figure(4)
plt.plot(t, midAngle, 'r')
plt.xlabel('Time, t [s]')
plt.ylabel('Angle, $\\alpha$ [deg]')
plt.savefig('fallingBeam_angle.png')

plt.show()
# Out:
# t=0.000000
# Iter=0, error=3.848697e+00
# Iter=1, error=4.483519e-03
# Iter=2, error=3.126264e-12
# t=0.010000
# Iter=0, error=4.187749e+00
# Iter=1, error=5.332964e-03
# Iter=2, error=2.890606e-11
# t=0.020000
# Iter=0, error=4.215837e+00
# Iter=1, error=5.393523e-03
# Iter=2, error=3.802996e-11
# t=0.030000
# Iter=0, error=4.216366e+00
# Iter=1, error=5.380528e-03
# Iter=2, error=4.316645e-11
# t=0.040000
# Iter=0, error=4.214450e+00
# Iter=1, error=5.361046e-03
# Iter=2, error=4.783013e-11
# t=0.050000
# Iter=0, error=4.212316e+00
# Iter=1, error=5.341038e-03
# Iter=2, error=5.241796e-11
# t=0.060000
# Iter=0, error=4.210160e+00
# Iter=1, error=5.321031e-03
# Iter=2, error=5.688277e-11
# t=0.070000
# Iter=0, error=4.207999e+00
# Iter=1, error=5.301071e-03
# Iter=2, error=6.131925e-11
# t=0.080000
# Iter=0, error=4.205836e+00
# Iter=1, error=5.281162e-03
# Iter=2, error=6.562929e-11
# t=0.090000
# Iter=0, error=4.203670e+00
# Iter=1, error=5.261305e-03
# Iter=2, error=6.985624e-11
# t=0.100000
# Iter=0, error=4.201502e+00
# Iter=1, error=5.241499e-03
# Iter=2, error=7.405107e-11
# t=0.110000
# Iter=0, error=4.199331e+00
# Iter=1, error=5.221743e-03
# Iter=2, error=7.811563e-11
# t=0.120000
# Iter=0, error=4.197157e+00
# Iter=1, error=5.202037e-03
# Iter=2, error=8.215884e-11
# t=0.130000
# Iter=0, error=4.194981e+00
# Iter=1, error=5.182382e-03
# Iter=2, error=8.606373e-11
# t=0.140000
# Iter=0, error=4.192803e+00
# Iter=1, error=5.162776e-03
# Iter=2, error=8.992965e-11
# t=0.150000
# Iter=0, error=4.190622e+00
# Iter=1, error=5.143220e-03
# Iter=2, error=9.370827e-11
# t=0.160000
# Iter=0, error=4.188439e+00
# Iter=1, error=5.123712e-03
# Iter=2, error=9.741614e-11
# t=0.170000
# Iter=0, error=4.186253e+00
# Iter=1, error=5.104254e-03
# Iter=2, error=1.010047e-10
# t=0.180000
# Iter=0, error=4.184065e+00
# Iter=1, error=5.084843e-03
# Iter=2, error=1.046050e-10
# t=0.190000
# Iter=0, error=4.181875e+00
# Iter=1, error=5.065482e-03
# Iter=2, error=1.080918e-10
# t=0.200000
# Iter=0, error=4.179683e+00
# Iter=1, error=5.046168e-03
# Iter=2, error=1.114542e-10
# t=0.210000
# Iter=0, error=4.177488e+00
# Iter=1, error=5.026901e-03
# Iter=2, error=1.148255e-10
# t=0.220000
# Iter=0, error=4.175291e+00
# Iter=1, error=5.007683e-03
# Iter=2, error=1.180950e-10
# t=0.230000
# Iter=0, error=4.173092e+00
# Iter=1, error=4.988511e-03
# Iter=2, error=1.212712e-10
# t=0.240000
# Iter=0, error=4.170891e+00
# Iter=1, error=4.969386e-03
# Iter=2, error=1.244240e-10
# t=0.250000
# Iter=0, error=4.168688e+00
# Iter=1, error=4.950308e-03
# Iter=2, error=1.274408e-10
# t=0.260000
# Iter=0, error=4.166483e+00
# Iter=1, error=4.931276e-03
# Iter=2, error=1.304920e-10
# t=0.270000
# Iter=0, error=4.164275e+00
# Iter=1, error=4.912291e-03
# Iter=2, error=1.333850e-10
# t=0.280000
# Iter=0, error=4.162066e+00
# Iter=1, error=4.893351e-03
# Iter=2, error=1.362451e-10
# t=0.290000
# Iter=0, error=4.159855e+00
# Iter=1, error=4.874457e-03
# Iter=2, error=1.390616e-10
# t=0.300000
# Iter=0, error=4.157642e+00
# Iter=1, error=4.855609e-03
# Iter=2, error=1.417209e-10
# t=0.310000
# Iter=0, error=4.155426e+00
# Iter=1, error=4.836806e-03
# Iter=2, error=1.444392e-10
# t=0.320000
# Iter=0, error=4.153209e+00
# Iter=1, error=4.818047e-03
# Iter=2, error=1.470017e-10
# t=0.330000
# Iter=0, error=4.150991e+00
# Iter=1, error=4.799334e-03
# Iter=2, error=1.496007e-10
# t=0.340000
# Iter=0, error=4.148770e+00
# Iter=1, error=4.780665e-03
# Iter=2, error=1.519977e-10
# t=0.350000
# Iter=0, error=4.146548e+00
# Iter=1, error=4.762041e-03
# Iter=2, error=1.544498e-10
# t=0.360000
# Iter=0, error=4.144323e+00
# Iter=1, error=4.743461e-03
# Iter=2, error=1.567495e-10
# t=0.370000
# Iter=0, error=4.142097e+00
# Iter=1, error=4.724924e-03
# Iter=2, error=1.590768e-10
# t=0.380000
# Iter=0, error=4.139870e+00
# Iter=1, error=4.706432e-03
# Iter=2, error=1.613070e-10
# t=0.390000
# Iter=0, error=4.137641e+00
# Iter=1, error=4.687983e-03
# Iter=2, error=1.634539e-10
# t=0.400000
# Iter=0, error=4.135410e+00
# Iter=1, error=4.669578e-03
# Iter=2, error=1.656359e-10
# t=0.410000
# Iter=0, error=4.133178e+00
# Iter=1, error=4.651216e-03
# Iter=2, error=1.676393e-10
# t=0.420000
# Iter=0, error=4.130944e+00
# Iter=1, error=4.632897e-03
# Iter=2, error=1.696210e-10
# t=0.430000
# Iter=0, error=4.128708e+00
# Iter=1, error=4.614621e-03
# Iter=2, error=1.716003e-10
# t=0.440000
# Iter=0, error=4.126471e+00
# Iter=1, error=4.596388e-03
# Iter=2, error=1.734842e-10
# t=0.450000
# Iter=0, error=4.124233e+00
# Iter=1, error=4.578197e-03
# Iter=2, error=1.753387e-10
# t=0.460000
# Iter=0, error=4.121994e+00
# Iter=1, error=4.560049e-03
# Iter=2, error=1.770303e-10
# t=0.470000
# Iter=0, error=4.119753e+00
# Iter=1, error=4.541943e-03
# Iter=2, error=1.787347e-10
# t=0.480000
# Iter=0, error=4.117510e+00
# Iter=1, error=4.523879e-03
# Iter=2, error=1.803564e-10
# t=0.490000
# Iter=0, error=4.115266e+00
# Iter=1, error=4.505857e-03
# Iter=2, error=1.820163e-10
# t=0.500000
# Iter=0, error=4.113022e+00
# Iter=1, error=4.487877e-03
# Iter=2, error=1.836260e-10
# t=0.510000
# Iter=0, error=4.110775e+00
# Iter=1, error=4.469938e-03
# Iter=2, error=1.851002e-10
# t=0.520000
# Iter=0, error=4.108528e+00
# Iter=1, error=4.452041e-03
# Iter=2, error=1.865595e-10
# t=0.530000
# Iter=0, error=4.106280e+00
# Iter=1, error=4.434186e-03
# Iter=2, error=1.880217e-10
# t=0.540000
# Iter=0, error=4.104030e+00
# Iter=1, error=4.416372e-03
# Iter=2, error=1.893586e-10
# t=0.550000
# Iter=0, error=4.101779e+00
# Iter=1, error=4.398599e-03
# Iter=2, error=1.906629e-10
# t=0.560000
# Iter=0, error=4.099528e+00
# Iter=1, error=4.380867e-03
# Iter=2, error=1.918643e-10
# t=0.570000
# Iter=0, error=4.097275e+00
# Iter=1, error=4.363175e-03
# Iter=2, error=1.931847e-10
# t=0.580000
# Iter=0, error=4.095021e+00
# Iter=1, error=4.345525e-03
# Iter=2, error=1.942375e-10
# t=0.590000
# Iter=0, error=4.092767e+00
# Iter=1, error=4.327915e-03
# Iter=2, error=1.953674e-10
# t=0.600000
# Iter=0, error=4.090511e+00
# Iter=1, error=4.310346e-03
# Iter=2, error=1.964016e-10
# t=0.610000
# Iter=0, error=4.088255e+00
# Iter=1, error=4.292818e-03
# Iter=2, error=1.975400e-10
# t=0.620000
# Iter=0, error=4.085998e+00
# Iter=1, error=4.275329e-03
# Iter=2, error=1.984968e-10
# t=0.630000
# Iter=0, error=4.083740e+00
# Iter=1, error=4.257881e-03
# Iter=2, error=1.994963e-10
# t=0.640000
# Iter=0, error=4.081481e+00
# Iter=1, error=4.240473e-03
# Iter=2, error=2.004453e-10
# t=0.650000
# Iter=0, error=4.079221e+00
# Iter=1, error=4.223105e-03
# Iter=2, error=2.011781e-10
# t=0.660000
# Iter=0, error=4.076961e+00
# Iter=1, error=4.205777e-03
# Iter=2, error=2.020509e-10
# t=0.670000
# Iter=0, error=4.074700e+00
# Iter=1, error=4.188489e-03
# Iter=2, error=2.027927e-10
# t=0.680000
# Iter=0, error=4.072439e+00
# Iter=1, error=4.171241e-03
# Iter=2, error=2.035942e-10
# t=0.690000
# Iter=0, error=4.070177e+00
# Iter=1, error=4.154032e-03
# Iter=2, error=2.042632e-10
# t=0.700000
# Iter=0, error=4.067914e+00
# Iter=1, error=4.136863e-03
# Iter=2, error=2.049016e-10
# t=0.710000
# Iter=0, error=4.065651e+00
# Iter=1, error=4.119734e-03
# Iter=2, error=2.054240e-10
# t=0.720000
# Iter=0, error=4.063388e+00
# Iter=1, error=4.102644e-03
# Iter=2, error=2.060926e-10
# t=0.730000
# Iter=0, error=4.061124e+00
# Iter=1, error=4.085594e-03
# Iter=2, error=2.065283e-10
# t=0.740000
# Iter=0, error=4.058859e+00
# Iter=1, error=4.068582e-03
# Iter=2, error=2.070439e-10
# t=0.750000
# Iter=0, error=4.056594e+00
# Iter=1, error=4.051610e-03
# Iter=2, error=2.075613e-10
# t=0.760000
# Iter=0, error=4.054329e+00
# Iter=1, error=4.034678e-03
# Iter=2, error=2.079860e-10
# t=0.770000
# Iter=0, error=4.052064e+00
# Iter=1, error=4.017784e-03
# Iter=2, error=2.084482e-10
# t=0.780000
# Iter=0, error=4.049798e+00
# Iter=1, error=4.000929e-03
# Iter=2, error=2.086217e-10
# t=0.790000
# Iter=0, error=4.047532e+00
# Iter=1, error=3.984114e-03
# Iter=2, error=2.090663e-10
# t=0.800000
# Iter=0, error=4.045266e+00
# Iter=1, error=3.967337e-03
# Iter=2, error=2.091994e-10
# t=0.810000
# Iter=0, error=4.043000e+00
# Iter=1, error=3.950599e-03
# Iter=2, error=2.095378e-10
# t=0.820000
# Iter=0, error=4.040734e+00
# Iter=1, error=3.933901e-03
# Iter=2, error=2.097638e-10
# t=0.830000
# Iter=0, error=4.038467e+00
# Iter=1, error=3.917241e-03
# Iter=2, error=2.100122e-10
# t=0.840000
# Iter=0, error=4.036201e+00
# Iter=1, error=3.900619e-03
# Iter=2, error=2.100633e-10
# t=0.850000
# Iter=0, error=4.033935e+00
# Iter=1, error=3.884037e-03
# Iter=2, error=2.102645e-10
# t=0.860000
# Iter=0, error=4.031668e+00
# Iter=1, error=3.867493e-03
# Iter=2, error=2.103230e-10
# t=0.870000
# Iter=0, error=4.029402e+00
# Iter=1, error=3.850988e-03
# Iter=2, error=2.104495e-10
# t=0.880000
# Iter=0, error=4.027135e+00
# Iter=1, error=3.834521e-03
# Iter=2, error=2.104437e-10
# t=0.890000
# Iter=0, error=4.024869e+00
# Iter=1, error=3.818093e-03
# Iter=2, error=2.105070e-10
# t=0.900000
# Iter=0, error=4.022603e+00
# Iter=1, error=3.801704e-03
# Iter=2, error=2.104083e-10
# t=0.910000
# Iter=0, error=4.020338e+00
# Iter=1, error=3.785353e-03
# Iter=2, error=2.102533e-10
# t=0.920000
# Iter=0, error=4.018072e+00
# Iter=1, error=3.769040e-03
# Iter=2, error=2.103984e-10
# t=0.930000
# Iter=0, error=4.015807e+00
# Iter=1, error=3.752766e-03
# Iter=2, error=2.102659e-10
# t=0.940000
# Iter=0, error=4.013542e+00
# Iter=1, error=3.736531e-03
# Iter=2, error=2.101709e-10
# t=0.950000
# Iter=0, error=4.011277e+00
# Iter=1, error=3.720334e-03
# Iter=2, error=2.098749e-10
# t=0.960000
# Iter=0, error=4.009013e+00
# Iter=1, error=3.704175e-03
# Iter=2, error=2.096849e-10
# t=0.970000
# Iter=0, error=4.006749e+00
# Iter=1, error=3.688054e-03
# Iter=2, error=2.093863e-10
# t=0.980000
# Iter=0, error=4.004486e+00
# Iter=1, error=3.671972e-03
# Iter=2, error=2.092796e-10
# t=0.990000
# Iter=0, error=4.002223e+00
# Iter=1, error=3.655929e-03
# Iter=2, error=2.089659e-10
# t=1.000000
# Iter=0, error=3.999960e+00
# Iter=1, error=3.639923e-03
# Iter=2, error=2.086592e-10
# t=1.010000
# Iter=0, error=3.997699e+00
# Iter=1, error=3.623956e-03
# Iter=2, error=2.083154e-10
# t=1.020000
# Iter=0, error=3.995437e+00
# Iter=1, error=3.608028e-03
# Iter=2, error=2.080396e-10
# t=1.030000
# Iter=0, error=3.993177e+00
# Iter=1, error=3.592137e-03
# Iter=2, error=2.078284e-10
# t=1.040000
# Iter=0, error=3.990917e+00
# Iter=1, error=3.576285e-03
# Iter=2, error=2.072770e-10
# t=1.050000
# Iter=0, error=3.988657e+00
# Iter=1, error=3.560471e-03
# Iter=2, error=2.069181e-10
# t=1.060000
# Iter=0, error=3.986399e+00
# Iter=1, error=3.544696e-03
# Iter=2, error=2.065258e-10
# t=1.070000
# Iter=0, error=3.984141e+00
# Iter=1, error=3.528959e-03
# Iter=2, error=2.061499e-10
# t=1.080000
# Iter=0, error=3.981884e+00
# Iter=1, error=3.513260e-03
# Iter=2, error=2.054999e-10
# t=1.090000
# Iter=0, error=3.979628e+00
# Iter=1, error=3.497599e-03
# Iter=2, error=2.051894e-10
# t=1.100000
# Iter=0, error=3.977372e+00
# Iter=1, error=3.481977e-03
# Iter=2, error=2.047155e-10
# t=1.110000
# Iter=0, error=3.975118e+00
# Iter=1, error=3.466393e-03
# Iter=2, error=2.041939e-10
# t=1.120000
# Iter=0, error=3.972864e+00
# Iter=1, error=3.450847e-03
# Iter=2, error=2.037908e-10
# t=1.130000
# Iter=0, error=3.970612e+00
# Iter=1, error=3.435339e-03
# Iter=2, error=2.028384e-10
# t=1.140000
# Iter=0, error=3.968360e+00
# Iter=1, error=3.419870e-03
# Iter=2, error=2.023146e-10
# t=1.150000
# Iter=0, error=3.966109e+00
# Iter=1, error=3.404440e-03
# Iter=2, error=2.021709e-10
# t=1.160000
# Iter=0, error=3.963860e+00
# Iter=1, error=3.389047e-03
# Iter=2, error=2.012251e-10
# t=1.170000
# Iter=0, error=3.961611e+00
# Iter=1, error=3.373693e-03
# Iter=2, error=2.004640e-10
# t=1.180000
# Iter=0, error=3.959364e+00
# Iter=1, error=3.358377e-03
# Iter=2, error=1.997855e-10
# t=1.190000
# Iter=0, error=3.957118e+00
# Iter=1, error=3.343100e-03
# Iter=2, error=1.992931e-10
# t=1.200000
# Iter=0, error=3.954873e+00
# Iter=1, error=3.327861e-03
# Iter=2, error=1.986573e-10
# t=1.210000
# Iter=0, error=3.952629e+00
# Iter=1, error=3.312660e-03
# Iter=2, error=1.978412e-10
# t=1.220000
# Iter=0, error=3.950387e+00
# Iter=1, error=3.297498e-03
# Iter=2, error=1.972572e-10
# t=1.230000
# Iter=0, error=3.948145e+00
# Iter=1, error=3.282375e-03
# Iter=2, error=1.965331e-10
# t=1.240000
# Iter=0, error=3.945905e+00
# Iter=1, error=3.267289e-03
# Iter=2, error=1.957424e-10
# t=1.250000
# Iter=0, error=3.943667e+00
# Iter=1, error=3.252243e-03
# Iter=2, error=1.950936e-10
# t=1.260000
# Iter=0, error=3.941430e+00
# Iter=1, error=3.237234e-03
# Iter=2, error=1.944112e-10
# t=1.270000
# Iter=0, error=3.939194e+00
# Iter=1, error=3.222265e-03
# Iter=2, error=1.936996e-10
# t=1.280000
# Iter=0, error=3.936959e+00
# Iter=1, error=3.207333e-03
# Iter=2, error=1.927666e-10
# t=1.290000
# Iter=0, error=3.934727e+00
# Iter=1, error=3.192441e-03
# Iter=2, error=1.919624e-10
# t=1.300000
# Iter=0, error=3.932495e+00
# Iter=1, error=3.177587e-03
# Iter=2, error=1.911884e-10
# t=1.310000
# Iter=0, error=3.930265e+00
# Iter=1, error=3.162772e-03
# Iter=2, error=1.901522e-10
# t=1.320000
# Iter=0, error=3.928037e+00
# Iter=1, error=3.147995e-03
# Iter=2, error=1.893582e-10
# t=1.330000
# Iter=0, error=3.925810e+00
# Iter=1, error=3.133257e-03
# Iter=2, error=1.886699e-10
# t=1.340000
# Iter=0, error=3.923585e+00
# Iter=1, error=3.118557e-03
# Iter=2, error=1.876864e-10
# t=1.350000
# Iter=0, error=3.921362e+00
# Iter=1, error=3.103897e-03
# Iter=2, error=1.868555e-10
# t=1.360000
# Iter=0, error=3.919140e+00
# Iter=1, error=3.089275e-03
# Iter=2, error=1.861053e-10
# t=1.370000
# Iter=0, error=3.916920e+00
# Iter=1, error=3.074692e-03
# Iter=2, error=1.854447e-10
# t=1.380000
# Iter=0, error=3.914702e+00
# Iter=1, error=3.060148e-03
# Iter=2, error=1.842709e-10
# t=1.390000
# Iter=0, error=3.912485e+00
# Iter=1, error=3.045642e-03
# Iter=2, error=1.832946e-10
# t=1.400000
# Iter=0, error=3.910271e+00
# Iter=1, error=3.031176e-03
# Iter=2, error=1.824502e-10
# t=1.410000
# Iter=0, error=3.908058e+00
# Iter=1, error=3.016748e-03
# Iter=2, error=1.817264e-10
# t=1.420000
# Iter=0, error=3.905847e+00
# Iter=1, error=3.002360e-03
# Iter=2, error=1.808861e-10
# t=1.430000
# Iter=0, error=3.903638e+00
# Iter=1, error=2.988010e-03
# Iter=2, error=1.796754e-10
# t=1.440000
# Iter=0, error=3.901431e+00
# Iter=1, error=2.973699e-03
# Iter=2, error=1.786950e-10
# t=1.450000
# Iter=0, error=3.899225e+00
# Iter=1, error=2.959428e-03
# Iter=2, error=1.777937e-10
# t=1.460000
# Iter=0, error=3.897022e+00
# Iter=1, error=2.945195e-03
# Iter=2, error=1.766924e-10
# t=1.470000
# Iter=0, error=3.894821e+00
# Iter=1, error=2.931002e-03
# Iter=2, error=1.758319e-10
# t=1.480000
# Iter=0, error=3.892622e+00
# Iter=1, error=2.916847e-03
# Iter=2, error=1.750660e-10
# t=1.490000
# Iter=0, error=3.890425e+00
# Iter=1, error=2.902732e-03
# Iter=2, error=1.740536e-10
# t=1.500000
# Iter=0, error=3.888230e+00
# Iter=1, error=2.888656e-03
# Iter=2, error=1.731144e-10
# t=1.510000
# Iter=0, error=3.886037e+00
# Iter=1, error=2.874620e-03
# Iter=2, error=1.721664e-10
# t=1.520000
# Iter=0, error=3.883846e+00
# Iter=1, error=2.860622e-03
# Iter=2, error=1.710796e-10
# t=1.530000
# Iter=0, error=3.881658e+00
# Iter=1, error=2.846664e-03
# Iter=2, error=1.699285e-10
# t=1.540000
# Iter=0, error=3.879471e+00
# Iter=1, error=2.832746e-03
# Iter=2, error=1.690696e-10
# t=1.550000
# Iter=0, error=3.877287e+00
# Iter=1, error=2.818866e-03
# Iter=2, error=1.682188e-10
# t=1.560000
# Iter=0, error=3.875105e+00
# Iter=1, error=2.805026e-03
# Iter=2, error=1.669031e-10
# t=1.570000
# Iter=0, error=3.872926e+00
# Iter=1, error=2.791226e-03
# Iter=2, error=1.660584e-10
# t=1.580000
# Iter=0, error=3.870748e+00
# Iter=1, error=2.777465e-03
# Iter=2, error=1.649769e-10
# t=1.590000
# Iter=0, error=3.868574e+00
# Iter=1, error=2.763744e-03
# Iter=2, error=1.639338e-10
# t=1.600000
# Iter=0, error=3.866401e+00
# Iter=1, error=2.750062e-03
# Iter=2, error=1.628196e-10
# t=1.610000
# Iter=0, error=3.864231e+00
# Iter=1, error=2.736420e-03
# Iter=2, error=1.617715e-10
# t=1.620000
# Iter=0, error=3.862063e+00
# Iter=1, error=2.722817e-03
# Iter=2, error=1.609032e-10
# t=1.630000
# Iter=0, error=3.859898e+00
# Iter=1, error=2.709254e-03
# Iter=2, error=1.597608e-10
# t=1.640000
# Iter=0, error=3.857735e+00
# Iter=1, error=2.695731e-03
# Iter=2, error=1.587700e-10
# t=1.650000
# Iter=0, error=3.855575e+00
# Iter=1, error=2.682248e-03
# Iter=2, error=1.578360e-10
# t=1.660000
# Iter=0, error=3.853417e+00
# Iter=1, error=2.668804e-03
# Iter=2, error=1.564013e-10
# t=1.670000
# Iter=0, error=3.851262e+00
# Iter=1, error=2.655400e-03
# Iter=2, error=1.555932e-10
# t=1.680000
# Iter=0, error=3.849109e+00
# Iter=1, error=2.642036e-03
# Iter=2, error=1.545806e-10
# t=1.690000
# Iter=0, error=3.846959e+00
# Iter=1, error=2.628712e-03
# Iter=2, error=1.535080e-10
# t=1.700000
# Iter=0, error=3.844812e+00
# Iter=1, error=2.615428e-03
# Iter=2, error=1.525763e-10
# t=1.710000
# Iter=0, error=3.842667e+00
# Iter=1, error=2.602184e-03
# Iter=2, error=1.511413e-10
# t=1.720000
# Iter=0, error=3.840525e+00
# Iter=1, error=2.588980e-03
# Iter=2, error=1.502172e-10
# t=1.730000
# Iter=0, error=3.838386e+00
# Iter=1, error=2.575816e-03
# Iter=2, error=1.491705e-10
# t=1.740000
# Iter=0, error=3.836249e+00
# Iter=1, error=2.562692e-03
# Iter=2, error=1.483138e-10
# t=1.750000
# Iter=0, error=3.834115e+00
# Iter=1, error=2.549608e-03
# Iter=2, error=1.471262e-10
# t=1.760000
# Iter=0, error=3.831984e+00
# Iter=1, error=2.536564e-03
# Iter=2, error=1.461116e-10
# t=1.770000
# Iter=0, error=3.829856e+00
# Iter=1, error=2.523561e-03
# Iter=2, error=1.451157e-10
# t=1.780000
# Iter=0, error=3.827730e+00
# Iter=1, error=2.510597e-03
# Iter=2, error=1.438445e-10
# t=1.790000
# Iter=0, error=3.825608e+00
# Iter=1, error=2.497674e-03
# Iter=2, error=1.430619e-10
# t=1.800000
# Iter=0, error=3.823488e+00
# Iter=1, error=2.484791e-03
# Iter=2, error=1.418563e-10
# t=1.810000
# Iter=0, error=3.821371e+00
# Iter=1, error=2.471949e-03
# Iter=2, error=1.409617e-10
# t=1.820000
# Iter=0, error=3.819257e+00
# Iter=1, error=2.459146e-03
# Iter=2, error=1.399752e-10
# t=1.830000
# Iter=0, error=3.817146e+00
# Iter=1, error=2.446385e-03
# Iter=2, error=1.387360e-10
# t=1.840000
# Iter=0, error=3.815038e+00
# Iter=1, error=2.433663e-03
# Iter=2, error=1.379480e-10
# t=1.850000
# Iter=0, error=3.812933e+00
# Iter=1, error=2.420982e-03
# Iter=2, error=1.367673e-10
# t=1.860000
# Iter=0, error=3.810831e+00
# Iter=1, error=2.408342e-03
# Iter=2, error=1.359114e-10
# t=1.870000
# Iter=0, error=3.808732e+00
# Iter=1, error=2.395742e-03
# Iter=2, error=1.344472e-10
# t=1.880000
# Iter=0, error=3.806636e+00
# Iter=1, error=2.383182e-03
# Iter=2, error=1.336847e-10
# t=1.890000
# Iter=0, error=3.804543e+00
# Iter=1, error=2.370663e-03
# Iter=2, error=1.322961e-10
# t=1.900000
# Iter=0, error=3.802453e+00
# Iter=1, error=2.358185e-03
# Iter=2, error=1.310985e-10
# t=1.910000
# Iter=0, error=3.800366e+00
# Iter=1, error=2.345747e-03
# Iter=2, error=1.304959e-10
# t=1.920000
# Iter=0, error=3.798282e+00
# Iter=1, error=2.333350e-03
# Iter=2, error=1.293621e-10
# t=1.930000
# Iter=0, error=3.796202e+00
# Iter=1, error=2.320993e-03
# Iter=2, error=1.284348e-10
# t=1.940000
# Iter=0, error=3.794125e+00
# Iter=1, error=2.308677e-03
# Iter=2, error=1.274644e-10
# t=1.950000
# Iter=0, error=3.792051e+00
# Iter=1, error=2.296402e-03
# Iter=2, error=1.260827e-10
# t=1.960000
# Iter=0, error=3.789980e+00
# Iter=1, error=2.284168e-03
# Iter=2, error=1.253906e-10
# t=1.970000
# Iter=0, error=3.787912e+00
# Iter=1, error=2.271974e-03
# Iter=2, error=1.242849e-10
# t=1.980000
# Iter=0, error=3.785848e+00
# Iter=1, error=2.259822e-03
# Iter=2, error=1.234473e-10
# t=1.990000
# Iter=0, error=3.783787e+00
# Iter=1, error=2.247710e-03
# Iter=2, error=1.221835e-10
# t=2.000000
# Iter=0, error=3.781729e+00
# Iter=1, error=2.235639e-03
# Iter=2, error=1.212407e-10
# t=2.010000
# Iter=0, error=3.779674e+00
# Iter=1, error=2.223608e-03
# Iter=2, error=1.200974e-10
# t=2.020000
# Iter=0, error=3.777623e+00
# Iter=1, error=2.211619e-03
# Iter=2, error=1.189890e-10
# t=2.030000
# Iter=0, error=3.775575e+00
# Iter=1, error=2.199670e-03
# Iter=2, error=1.180468e-10
# t=2.040000
# Iter=0, error=3.773531e+00
# Iter=1, error=2.187763e-03
# Iter=2, error=1.173753e-10
# t=2.050000
# Iter=0, error=3.771490e+00
# Iter=1, error=2.175896e-03
# Iter=2, error=1.161203e-10
# t=2.060000
# Iter=0, error=3.769452e+00
# Iter=1, error=2.164071e-03
# Iter=2, error=1.148548e-10
# t=2.070000
# Iter=0, error=3.767418e+00
# Iter=1, error=2.152286e-03
# Iter=2, error=1.137621e-10
# t=2.080000
# Iter=0, error=3.765387e+00
# Iter=1, error=2.140542e-03
# Iter=2, error=1.131053e-10
# t=2.090000
# Iter=0, error=3.763360e+00
# Iter=1, error=2.128839e-03
# Iter=2, error=1.119465e-10
# t=2.100000
# Iter=0, error=3.761336e+00
# Iter=1, error=2.117178e-03
# Iter=2, error=1.110332e-10
# t=2.110000
# Iter=0, error=3.759316e+00
# Iter=1, error=2.105557e-03
# Iter=2, error=1.096935e-10
# t=2.120000
# Iter=0, error=3.757299e+00
# Iter=1, error=2.093978e-03
# Iter=2, error=1.091542e-10
# t=2.130000
# Iter=0, error=3.755286e+00
# Iter=1, error=2.082439e-03
# Iter=2, error=1.083504e-10
# t=2.140000
# Iter=0, error=3.753276e+00
# Iter=1, error=2.070942e-03
# Iter=2, error=1.072809e-10
# t=2.150000
# Iter=0, error=3.751270e+00
# Iter=1, error=2.059485e-03
# Iter=2, error=1.063980e-10
# t=2.160000
# Iter=0, error=3.749268e+00
# Iter=1, error=2.048070e-03
# Iter=2, error=1.053251e-10
# t=2.170000
# Iter=0, error=3.747269e+00
# Iter=1, error=2.036696e-03
# Iter=2, error=1.045922e-10
# t=2.180000
# Iter=0, error=3.745274e+00
# Iter=1, error=2.025363e-03
# Iter=2, error=1.030344e-10
# t=2.190000
# Iter=0, error=3.743282e+00
# Iter=1, error=2.014071e-03
# Iter=2, error=1.023802e-10
# t=2.200000
# Iter=0, error=3.741294e+00
# Iter=1, error=2.002820e-03
# Iter=2, error=1.014731e-10
# t=2.210000
# Iter=0, error=3.739310e+00
# Iter=1, error=1.991611e-03
# Iter=2, error=1.004768e-10
# t=2.220000
# Iter=0, error=3.737329e+00
# Iter=1, error=1.980442e-03
# Iter=2, error=9.944044e-11
# t=2.230000
# Iter=0, error=3.735352e+00
# Iter=1, error=1.969315e-03
# Iter=2, error=9.872152e-11
# t=2.240000
# Iter=0, error=3.733379e+00
# Iter=1, error=1.958229e-03
# Iter=2, error=9.761630e-11
# t=2.250000
# Iter=0, error=3.731409e+00
# Iter=1, error=1.947184e-03
# Iter=2, error=9.693309e-11
# t=2.260000
# Iter=0, error=3.729444e+00
# Iter=1, error=1.936181e-03
# Iter=2, error=9.593269e-11
# t=2.270000
# Iter=0, error=3.727482e+00
# Iter=1, error=1.925218e-03
# Iter=2, error=9.477259e-11
# t=2.280000
# Iter=0, error=3.725523e+00
# Iter=1, error=1.914297e-03
# Iter=2, error=9.408353e-11
# t=2.290000
# Iter=0, error=3.723569e+00
# Iter=1, error=1.903416e-03
# Iter=2, error=9.322889e-11
# t=2.300000
# Iter=0, error=3.721618e+00
# Iter=1, error=1.892577e-03
# Iter=2, error=9.243388e-11
# t=2.310000
# Iter=0, error=3.719672e+00
# Iter=1, error=1.881779e-03
# Iter=2, error=9.130214e-11
# t=2.320000
# Iter=0, error=3.717729e+00
# Iter=1, error=1.871023e-03
# Iter=2, error=9.082002e-11
# t=2.330000
# Iter=0, error=3.715789e+00
# Iter=1, error=1.860307e-03
# Iter=2, error=8.964701e-11
# t=2.340000
# Iter=0, error=3.713854e+00
# Iter=1, error=1.849633e-03
# Iter=2, error=8.871107e-11
# t=2.350000
# Iter=0, error=3.711923e+00
# Iter=1, error=1.838999e-03
# Iter=2, error=8.780902e-11
# t=2.360000
# Iter=0, error=3.709995e+00
# Iter=1, error=1.828407e-03
# Iter=2, error=8.696121e-11
# t=2.370000
# Iter=0, error=3.708072e+00
# Iter=1, error=1.817856e-03
# Iter=2, error=8.603007e-11
# t=2.380000
# Iter=0, error=3.706152e+00
# Iter=1, error=1.807347e-03
# Iter=2, error=8.519950e-11
# t=2.390000
# Iter=0, error=3.704236e+00
# Iter=1, error=1.796878e-03
# Iter=2, error=8.439558e-11
# t=2.400000
# Iter=0, error=3.702325e+00
# Iter=1, error=1.786450e-03
# Iter=2, error=8.365801e-11
# t=2.410000
# Iter=0, error=3.700417e+00
# Iter=1, error=1.776064e-03
# Iter=2, error=8.268954e-11
# t=2.420000
# Iter=0, error=3.698513e+00
# Iter=1, error=1.765718e-03
# Iter=2, error=8.165106e-11
# t=2.430000
# Iter=0, error=3.696613e+00
# Iter=1, error=1.755414e-03
# Iter=2, error=8.091759e-11
# t=2.440000
# Iter=0, error=3.694717e+00
# Iter=1, error=1.745151e-03
# Iter=2, error=8.059859e-11
# t=2.450000
# Iter=0, error=3.692825e+00
# Iter=1, error=1.734929e-03
# Iter=2, error=7.950082e-11
# t=2.460000
# Iter=0, error=3.690938e+00
# Iter=1, error=1.724747e-03
# Iter=2, error=7.877155e-11
# t=2.470000
# Iter=0, error=3.689054e+00
# Iter=1, error=1.714607e-03
# Iter=2, error=7.786312e-11
# t=2.480000
# Iter=0, error=3.687174e+00
# Iter=1, error=1.704508e-03
# Iter=2, error=7.681899e-11
# t=2.490000
# Iter=0, error=3.685298e+00
# Iter=1, error=1.694450e-03
# Iter=2, error=7.594496e-11
# t=2.500000
# Iter=0, error=3.683426e+00
# Iter=1, error=1.684432e-03
# Iter=2, error=7.575860e-11
# t=2.510000
# Iter=0, error=3.681559e+00
# Iter=1, error=1.674456e-03
# Iter=2, error=7.500633e-11
# t=2.520000
# Iter=0, error=3.679695e+00
# Iter=1, error=1.664521e-03
# Iter=2, error=7.332175e-11
# t=2.530000
# Iter=0, error=3.677836e+00
# Iter=1, error=1.654626e-03
# Iter=2, error=7.295574e-11
# t=2.540000
# Iter=0, error=3.675980e+00
# Iter=1, error=1.644773e-03
# Iter=2, error=7.238517e-11
# t=2.550000
# Iter=0, error=3.674129e+00
# Iter=1, error=1.634960e-03
# Iter=2, error=7.152123e-11
# t=2.560000
# Iter=0, error=3.672282e+00
# Iter=1, error=1.625188e-03
# Iter=2, error=7.063148e-11
# t=2.570000
# Iter=0, error=3.670439e+00
# Iter=1, error=1.615457e-03
# Iter=2, error=6.996760e-11
# t=2.580000
# Iter=0, error=3.668600e+00
# Iter=1, error=1.605766e-03
# Iter=2, error=6.952208e-11
# t=2.590000
# Iter=0, error=3.666766e+00
# Iter=1, error=1.596116e-03
# Iter=2, error=6.868593e-11
# t=2.600000
# Iter=0, error=3.664935e+00
# Iter=1, error=1.586507e-03
# Iter=2, error=6.770710e-11
# t=2.610000
# Iter=0, error=3.663109e+00
# Iter=1, error=1.576939e-03
# Iter=2, error=6.703688e-11
# t=2.620000
# Iter=0, error=3.661287e+00
# Iter=1, error=1.567411e-03
# Iter=2, error=6.615278e-11
# t=2.630000
# Iter=0, error=3.659469e+00
# Iter=1, error=1.557924e-03
# Iter=2, error=6.572939e-11
# t=2.640000
# Iter=0, error=3.657655e+00
# Iter=1, error=1.548478e-03
# Iter=2, error=6.494780e-11
# t=2.650000
# Iter=0, error=3.655845e+00
# Iter=1, error=1.539072e-03
# Iter=2, error=6.417758e-11
# t=2.660000
# Iter=0, error=3.654040e+00
# Iter=1, error=1.529706e-03
# Iter=2, error=6.333224e-11
# t=2.670000
# Iter=0, error=3.652239e+00
# Iter=1, error=1.520381e-03
# Iter=2, error=6.277470e-11
# t=2.680000
# Iter=0, error=3.650442e+00
# Iter=1, error=1.511097e-03
# Iter=2, error=6.229236e-11
# t=2.690000
# Iter=0, error=3.648649e+00
# Iter=1, error=1.501853e-03
# Iter=2, error=6.153726e-11
# t=2.700000
# Iter=0, error=3.646861e+00
# Iter=1, error=1.492649e-03
# Iter=2, error=6.049790e-11
# t=2.710000
# Iter=0, error=3.645077e+00
# Iter=1, error=1.483485e-03
# Iter=2, error=6.051234e-11
# t=2.720000
# Iter=0, error=3.643297e+00
# Iter=1, error=1.474362e-03
# Iter=2, error=5.950475e-11
# t=2.730000
# Iter=0, error=3.641521e+00
# Iter=1, error=1.465279e-03
# Iter=2, error=5.902384e-11
# t=2.740000
# Iter=0, error=3.639750e+00
# Iter=1, error=1.456236e-03
# Iter=2, error=5.825003e-11
# t=2.750000
# Iter=0, error=3.637983e+00
# Iter=1, error=1.447234e-03
# Iter=2, error=5.718424e-11
# t=2.760000
# Iter=0, error=3.636220e+00
# Iter=1, error=1.438271e-03
# Iter=2, error=5.675489e-11
# t=2.770000
# Iter=0, error=3.634462e+00
# Iter=1, error=1.429349e-03
# Iter=2, error=5.619250e-11
# t=2.780000
# Iter=0, error=3.632708e+00
# Iter=1, error=1.420466e-03
# Iter=2, error=5.568719e-11
# t=2.790000
# Iter=0, error=3.630958e+00
# Iter=1, error=1.411624e-03
# Iter=2, error=5.487609e-11
# t=2.800000
# Iter=0, error=3.629212e+00
# Iter=1, error=1.402821e-03
# Iter=2, error=5.421980e-11
# t=2.810000
# Iter=0, error=3.627471e+00
# Iter=1, error=1.394058e-03
# Iter=2, error=5.371321e-11
# t=2.820000
# Iter=0, error=3.625734e+00
# Iter=1, error=1.385335e-03
# Iter=2, error=5.296122e-11
# t=2.830000
# Iter=0, error=3.624002e+00
# Iter=1, error=1.376652e-03
# Iter=2, error=5.215759e-11
# t=2.840000
# Iter=0, error=3.622274e+00
# Iter=1, error=1.368009e-03
# Iter=2, error=5.234952e-11
# t=2.850000
# Iter=0, error=3.620550e+00
# Iter=1, error=1.359405e-03
# Iter=2, error=5.157114e-11
# t=2.860000
# Iter=0, error=3.618830e+00
# Iter=1, error=1.350840e-03
# Iter=2, error=5.067619e-11
# t=2.870000
# Iter=0, error=3.617115e+00
# Iter=1, error=1.342316e-03
# Iter=2, error=4.991539e-11
# t=2.880000
# Iter=0, error=3.615404e+00
# Iter=1, error=1.333830e-03
# Iter=2, error=4.966774e-11
# t=2.890000
# Iter=0, error=3.613698e+00
# Iter=1, error=1.325384e-03
# Iter=2, error=4.873573e-11
# t=2.900000
# Iter=0, error=3.611996e+00
# Iter=1, error=1.316978e-03
# Iter=2, error=4.814480e-11
# t=2.910000
# Iter=0, error=3.610298e+00
# Iter=1, error=1.308611e-03
# Iter=2, error=4.788105e-11
# t=2.920000
# Iter=0, error=3.608605e+00
# Iter=1, error=1.300283e-03
# Iter=2, error=4.691993e-11
# t=2.930000
# Iter=0, error=3.606916e+00
# Iter=1, error=1.291994e-03
# Iter=2, error=4.717923e-11
# t=2.940000
# Iter=0, error=3.605232e+00
# Iter=1, error=1.283745e-03
# Iter=2, error=4.609016e-11
# t=2.950000
# Iter=0, error=3.603552e+00
# Iter=1, error=1.275534e-03
# Iter=2, error=4.535888e-11
# t=2.960000
# Iter=0, error=3.601876e+00
# Iter=1, error=1.267362e-03
# Iter=2, error=4.494015e-11
# t=2.970000
# Iter=0, error=3.600205e+00
# Iter=1, error=1.259230e-03
# Iter=2, error=4.455213e-11
# t=2.980000
# Iter=0, error=3.598538e+00
# Iter=1, error=1.251136e-03
# Iter=2, error=4.355929e-11
# t=2.990000
# Iter=0, error=3.596876e+00
# Iter=1, error=1.243081e-03
# Iter=2, error=4.347601e-11
# t=3.000000
# Iter=0, error=3.595218e+00
# Iter=1, error=1.235065e-03
# Iter=2, error=4.338943e-11
# t=3.010000
# Iter=0, error=3.593564e+00
# Iter=1, error=1.227087e-03
# Iter=2, error=4.249560e-11
# t=3.020000
# Iter=0, error=3.591915e+00
# Iter=1, error=1.219148e-03
# Iter=2, error=4.156559e-11
# t=3.030000
# Iter=0, error=3.590270e+00
# Iter=1, error=1.211248e-03
# Iter=2, error=4.149504e-11
# t=3.040000
# Iter=0, error=3.588630e+00
# Iter=1, error=1.203386e-03
# Iter=2, error=4.072837e-11
# t=3.050000
# Iter=0, error=3.586994e+00
# Iter=1, error=1.195562e-03
# Iter=2, error=4.084486e-11
# t=3.060000
# Iter=0, error=3.585363e+00
# Iter=1, error=1.187777e-03
# Iter=2, error=3.985962e-11
# t=3.070000
# Iter=0, error=3.583736e+00
# Iter=1, error=1.180030e-03
# Iter=2, error=3.939560e-11
# t=3.080000
# Iter=0, error=3.582113e+00
# Iter=1, error=1.172321e-03
# Iter=2, error=3.898483e-11
# t=3.090000
# Iter=0, error=3.580495e+00
# Iter=1, error=1.164650e-03
# Iter=2, error=3.825403e-11
# t=3.100000
# Iter=0, error=3.578881e+00
# Iter=1, error=1.157017e-03
# Iter=2, error=3.780592e-11
# t=3.110000
# Iter=0, error=3.577272e+00
# Iter=1, error=1.149423e-03
# Iter=2, error=3.740758e-11
# t=3.120000
# Iter=0, error=3.575667e+00
# Iter=1, error=1.141866e-03
# Iter=2, error=3.716561e-11
# t=3.130000
# Iter=0, error=3.574067e+00
# Iter=1, error=1.134346e-03
# Iter=2, error=3.633941e-11
# t=3.140000
# Iter=0, error=3.572471e+00
# Iter=1, error=1.126865e-03
# Iter=2, error=3.631146e-11
# t=3.150000
# Iter=0, error=3.570880e+00
# Iter=1, error=1.119421e-03
# Iter=2, error=3.551393e-11
# t=3.160000
# Iter=0, error=3.569293e+00
# Iter=1, error=1.112015e-03
# Iter=2, error=3.500807e-11
# t=3.170000
# Iter=0, error=3.567710e+00
# Iter=1, error=1.104646e-03
# Iter=2, error=3.494637e-11
# t=3.180000
# Iter=0, error=3.566132e+00
# Iter=1, error=1.097314e-03
# Iter=2, error=3.437425e-11
# t=3.190000
# Iter=0, error=3.564559e+00
# Iter=1, error=1.090020e-03
# Iter=2, error=3.396689e-11
# t=3.200000
# Iter=0, error=3.562990e+00
# Iter=1, error=1.082763e-03
# Iter=2, error=3.331899e-11
# t=3.210000
# Iter=0, error=3.561425e+00
# Iter=1, error=1.075543e-03
# Iter=2, error=3.334285e-11
# t=3.220000
# Iter=0, error=3.559865e+00
# Iter=1, error=1.068361e-03
# Iter=2, error=3.280514e-11
# t=3.230000
# Iter=0, error=3.558309e+00
# Iter=1, error=1.061215e-03
# Iter=2, error=3.225583e-11
# t=3.240000
# Iter=0, error=3.556758e+00
# Iter=1, error=1.054106e-03
# Iter=2, error=3.177076e-11
# t=3.250000
# Iter=0, error=3.555211e+00
# Iter=1, error=1.047034e-03
# Iter=2, error=3.131384e-11
# t=3.260000
# Iter=0, error=3.553669e+00
# Iter=1, error=1.039998e-03
# Iter=2, error=3.097744e-11
# t=3.270000
# Iter=0, error=3.552131e+00
# Iter=1, error=1.032999e-03
# Iter=2, error=3.075124e-11
# t=3.280000
# Iter=0, error=3.550597e+00
# Iter=1, error=1.026037e-03
# Iter=2, error=3.004056e-11
# t=3.290000
# Iter=0, error=3.549068e+00
# Iter=1, error=1.019111e-03
# Iter=2, error=2.963435e-11
# t=3.300000
# Iter=0, error=3.547544e+00
# Iter=1, error=1.012222e-03
# Iter=2, error=2.929142e-11
# t=3.310000
# Iter=0, error=3.546024e+00
# Iter=1, error=1.005368e-03
# Iter=2, error=2.892558e-11
# t=3.320000
# Iter=0, error=3.544508e+00
# Iter=1, error=9.985512e-04
# Iter=2, error=2.877050e-11
# t=3.330000
# Iter=0, error=3.542997e+00
# Iter=1, error=9.917701e-04
# Iter=2, error=2.829166e-11
# t=3.340000
# Iter=0, error=3.541491e+00
# Iter=1, error=9.850250e-04
# Iter=2, error=2.807788e-11
# t=3.350000
# Iter=0, error=3.539989e+00
# Iter=1, error=9.783158e-04
# Iter=2, error=2.723810e-11
# t=3.360000
# Iter=0, error=3.538491e+00
# Iter=1, error=9.716424e-04
# Iter=2, error=2.733018e-11
# t=3.370000
# Iter=0, error=3.536998e+00
# Iter=1, error=9.650046e-04
# Iter=2, error=2.692221e-11
# t=3.380000
# Iter=0, error=3.535509e+00
# Iter=1, error=9.584025e-04
# Iter=2, error=2.641991e-11
# t=3.390000
# Iter=0, error=3.534025e+00
# Iter=1, error=9.518359e-04
# Iter=2, error=2.625961e-11
# t=3.400000
# Iter=0, error=3.532545e+00
# Iter=1, error=9.453046e-04
# Iter=2, error=2.595901e-11
# t=3.410000
# Iter=0, error=3.531069e+00
# Iter=1, error=9.388087e-04
# Iter=2, error=2.527846e-11
# t=3.420000
# Iter=0, error=3.529598e+00
# Iter=1, error=9.323480e-04
# Iter=2, error=2.508054e-11
# t=3.430000
# Iter=0, error=3.528132e+00
# Iter=1, error=9.259224e-04
# Iter=2, error=2.456606e-11
# t=3.440000
# Iter=0, error=3.526670e+00
# Iter=1, error=9.195318e-04
# Iter=2, error=2.487008e-11
# t=3.450000
# Iter=0, error=3.525212e+00
# Iter=1, error=9.131761e-04
# Iter=2, error=2.429241e-11
# t=3.460000
# Iter=0, error=3.523759e+00
# Iter=1, error=9.068552e-04
# Iter=2, error=2.402336e-11
# t=3.470000
# Iter=0, error=3.522310e+00
# Iter=1, error=9.005690e-04
# Iter=2, error=2.351390e-11
# t=3.480000
# Iter=0, error=3.520866e+00
# Iter=1, error=8.943175e-04
# Iter=2, error=2.342235e-11
# t=3.490000
# Iter=0, error=3.519426e+00
# Iter=1, error=8.881004e-04
# Iter=2, error=2.275701e-11
# t=3.500000
# Iter=0, error=3.517991e+00
# Iter=1, error=8.819178e-04
# Iter=2, error=2.236673e-11
# t=3.510000
# Iter=0, error=3.516560e+00
# Iter=1, error=8.757694e-04
# Iter=2, error=2.216077e-11
# t=3.520000
# Iter=0, error=3.515133e+00
# Iter=1, error=8.696553e-04
# Iter=2, error=2.199271e-11
# t=3.530000
# Iter=0, error=3.513711e+00
# Iter=1, error=8.635752e-04
# Iter=2, error=2.177712e-11
# t=3.540000
# Iter=0, error=3.512294e+00
# Iter=1, error=8.575291e-04
# Iter=2, error=2.144593e-11
# t=3.550000
# Iter=0, error=3.510880e+00
# Iter=1, error=8.515170e-04
# Iter=2, error=2.146296e-11
# t=3.560000
# Iter=0, error=3.509472e+00
# Iter=1, error=8.455386e-04
# Iter=2, error=2.084197e-11
# t=3.570000
# Iter=0, error=3.508067e+00
# Iter=1, error=8.395938e-04
# Iter=2, error=2.073961e-11
# t=3.580000
# Iter=0, error=3.506667e+00
# Iter=1, error=8.336827e-04
# Iter=2, error=2.045856e-11
# t=3.590000
# Iter=0, error=3.505272e+00
# Iter=1, error=8.278050e-04
# Iter=2, error=2.005434e-11
# t=3.600000
# Iter=0, error=3.503881e+00
# Iter=1, error=8.219607e-04
# Iter=2, error=1.991614e-11
# t=3.610000
# Iter=0, error=3.502494e+00
# Iter=1, error=8.161496e-04
# Iter=2, error=1.975010e-11
# t=3.620000
# Iter=0, error=3.501111e+00
# Iter=1, error=8.103716e-04
# Iter=2, error=1.928311e-11
# t=3.630000
# Iter=0, error=3.499734e+00
# Iter=1, error=8.046267e-04
# Iter=2, error=1.895198e-11
# t=3.640000
# Iter=0, error=3.498360e+00
# Iter=1, error=7.989147e-04
# Iter=2, error=1.828683e-11
# t=3.650000
# Iter=0, error=3.496991e+00
# Iter=1, error=7.932355e-04
# Iter=2, error=1.861639e-11
# t=3.660000
# Iter=0, error=3.495626e+00
# Iter=1, error=7.875890e-04
# Iter=2, error=1.799804e-11
# t=3.670000
# Iter=0, error=3.494266e+00
# Iter=1, error=7.819751e-04
# Iter=2, error=1.798815e-11
# t=3.680000
# Iter=0, error=3.492910e+00
# Iter=1, error=7.763937e-04
# Iter=2, error=1.793424e-11
# t=3.690000
# Iter=0, error=3.491558e+00
# Iter=1, error=7.708446e-04
# Iter=2, error=1.736306e-11
# t=3.700000
# Iter=0, error=3.490211e+00
# Iter=1, error=7.653278e-04
# Iter=2, error=1.757042e-11
# t=3.710000
# Iter=0, error=3.488868e+00
# Iter=1, error=7.598432e-04
# Iter=2, error=1.676752e-11
# t=3.720000
# Iter=0, error=3.487529e+00
# Iter=1, error=7.543906e-04
# Iter=2, error=1.663266e-11
# t=3.730000
# Iter=0, error=3.486195e+00
# Iter=1, error=7.489699e-04
# Iter=2, error=1.677809e-11
# t=3.740000
# Iter=0, error=3.484866e+00
# Iter=1, error=7.435810e-04
# Iter=2, error=1.627112e-11
# t=3.750000
# Iter=0, error=3.483540e+00
# Iter=1, error=7.382238e-04
# Iter=2, error=1.627452e-11
# t=3.760000
# Iter=0, error=3.482219e+00
# Iter=1, error=7.328982e-04
# Iter=2, error=1.599514e-11
# t=3.770000
# Iter=0, error=3.480902e+00
# Iter=1, error=7.276041e-04
# Iter=2, error=1.583339e-11
# t=3.780000
# Iter=0, error=3.479590e+00
# Iter=1, error=7.223414e-04
# Iter=2, error=1.543828e-11
# t=3.790000
# Iter=0, error=3.478282e+00
# Iter=1, error=7.171099e-04
# Iter=2, error=1.578978e-11
# t=3.800000
# Iter=0, error=3.476978e+00
# Iter=1, error=7.119095e-04
# Iter=2, error=1.497012e-11
# t=3.810000
# Iter=0, error=3.475679e+00
# Iter=1, error=7.067401e-04
# Iter=2, error=1.505510e-11
# t=3.820000
# Iter=0, error=3.474383e+00
# Iter=1, error=7.016016e-04
# Iter=2, error=1.472689e-11
# t=3.830000
# Iter=0, error=3.473093e+00
# Iter=1, error=6.964939e-04
# Iter=2, error=1.428544e-11
# t=3.840000
# Iter=0, error=3.471806e+00
# Iter=1, error=6.914169e-04
# Iter=2, error=1.431627e-11
# t=3.850000
# Iter=0, error=3.470524e+00
# Iter=1, error=6.863704e-04
# Iter=2, error=1.407449e-11
# t=3.860000
# Iter=0, error=3.469246e+00
# Iter=1, error=6.813544e-04
# Iter=2, error=1.372658e-11
# t=3.870000
# Iter=0, error=3.467972e+00
# Iter=1, error=6.763687e-04
# Iter=2, error=1.353015e-11
# t=3.880000
# Iter=0, error=3.466703e+00
# Iter=1, error=6.714132e-04
# Iter=2, error=1.346735e-11
# t=3.890000
# Iter=0, error=3.465438e+00
# Iter=1, error=6.664878e-04
# Iter=2, error=1.319079e-11
# t=3.900000
# Iter=0, error=3.464177e+00
# Iter=1, error=6.615923e-04
# Iter=2, error=1.279317e-11
# t=3.910000
# Iter=0, error=3.462921e+00
# Iter=1, error=6.567267e-04
# Iter=2, error=1.258924e-11
# t=3.920000
# Iter=0, error=3.461669e+00
# Iter=1, error=6.518908e-04
# Iter=2, error=1.237589e-11
# t=3.930000
# Iter=0, error=3.460421e+00
# Iter=1, error=6.470846e-04
# Iter=2, error=1.231031e-11
# t=3.940000
# Iter=0, error=3.459177e+00
# Iter=1, error=6.423078e-04
# Iter=2, error=1.218367e-11
# t=3.950000
# Iter=0, error=3.457937e+00
# Iter=1, error=6.375605e-04
# Iter=2, error=1.197559e-11
# t=3.960000
# Iter=0, error=3.456702e+00
# Iter=1, error=6.328424e-04
# Iter=2, error=1.134316e-11
# t=3.970000
# Iter=0, error=3.455471e+00
# Iter=1, error=6.281534e-04
# Iter=2, error=1.157571e-11
# t=3.980000
# Iter=0, error=3.454244e+00
# Iter=1, error=6.234935e-04
# Iter=2, error=1.166205e-11
# t=3.990000
# Iter=0, error=3.453022e+00
# Iter=1, error=6.188625e-04
# Iter=2, error=1.139459e-11
# t=4.000000
# Iter=0, error=3.451803e+00
# Iter=1, error=6.142603e-04
# Iter=2, error=1.134277e-11
# t=4.010000
# Iter=0, error=3.450589e+00
# Iter=1, error=6.096867e-04
# Iter=2, error=1.081571e-11
# t=4.020000
# Iter=0, error=3.449379e+00
# Iter=1, error=6.051417e-04
# Iter=2, error=1.072456e-11
# t=4.030000
# Iter=0, error=3.448173e+00
# Iter=1, error=6.006252e-04
# Iter=2, error=1.103395e-11
# t=4.040000
# Iter=0, error=3.446972e+00
# Iter=1, error=5.961369e-04
# Iter=2, error=1.110346e-11
# t=4.050000
# Iter=0, error=3.445775e+00
# Iter=1, error=5.916769e-04
# Iter=2, error=1.067899e-11
# t=4.060000
# Iter=0, error=3.444581e+00
# Iter=1, error=5.872449e-04
# Iter=2, error=9.937088e-12
# t=4.070000
# Iter=0, error=3.443392e+00
# Iter=1, error=5.828409e-04
# Iter=2, error=1.032855e-11
# t=4.080000
# Iter=0, error=3.442207e+00
# Iter=1, error=5.784647e-04
# Iter=2, error=9.780812e-12
# t=4.090000
# Iter=0, error=3.441027e+00
# Iter=1, error=5.741162e-04
# Iter=2, error=9.642066e-12
# t=4.100000
# Iter=0, error=3.439850e+00
# Iter=1, error=5.697954e-04
# Iter=2, error=9.795223e-12
# t=4.110000
# Iter=0, error=3.438678e+00
# Iter=1, error=5.655020e-04
# Iter=2, error=9.233188e-12
# t=4.120000
# Iter=0, error=3.437509e+00
# Iter=1, error=5.612359e-04
# Iter=2, error=9.246403e-12
# t=4.130000
# Iter=0, error=3.436345e+00
# Iter=1, error=5.569972e-04
# Iter=2, error=9.541012e-12
# t=4.140000
# Iter=0, error=3.435185e+00
# Iter=1, error=5.527855e-04
# Iter=2, error=9.020146e-12
# t=4.150000
# Iter=0, error=3.434029e+00
# Iter=1, error=5.486008e-04
# Iter=2, error=8.895371e-12
# t=4.160000
# Iter=0, error=3.432877e+00
# Iter=1, error=5.444430e-04
# Iter=2, error=9.333031e-12
# t=4.170000
# Iter=0, error=3.431730e+00
# Iter=1, error=5.403120e-04
# Iter=2, error=8.619748e-12
# t=4.180000
# Iter=0, error=3.430586e+00
# Iter=1, error=5.362076e-04
# Iter=2, error=8.566861e-12
# t=4.190000
# Iter=0, error=3.429446e+00
# Iter=1, error=5.321297e-04
# Iter=2, error=8.481167e-12
# t=4.200000
# Iter=0, error=3.428311e+00
# Iter=1, error=5.280783e-04
# Iter=2, error=8.494071e-12
# t=4.210000
# Iter=0, error=3.427179e+00
# Iter=1, error=5.240531e-04
# Iter=2, error=8.506654e-12
# t=4.220000
# Iter=0, error=3.426052e+00
# Iter=1, error=5.200540e-04
# Iter=2, error=7.868367e-12
# t=4.230000
# Iter=0, error=3.424929e+00
# Iter=1, error=5.160810e-04
# Iter=2, error=8.086755e-12
# t=4.240000
# Iter=0, error=3.423809e+00
# Iter=1, error=5.121340e-04
# Iter=2, error=7.920541e-12
# t=4.250000
# Iter=0, error=3.422694e+00
# Iter=1, error=5.082127e-04
# Iter=2, error=7.857376e-12
# t=4.260000
# Iter=0, error=3.421583e+00
# Iter=1, error=5.043171e-04
# Iter=2, error=7.592305e-12
# t=4.270000
# Iter=0, error=3.420476e+00
# Iter=1, error=5.004470e-04
# Iter=2, error=7.831640e-12
# t=4.280000
# Iter=0, error=3.419373e+00
# Iter=1, error=4.966024e-04
# Iter=2, error=7.044712e-12
# t=4.290000
# Iter=0, error=3.418273e+00
# Iter=1, error=4.927832e-04
# Iter=2, error=7.152299e-12
# t=4.300000
# Iter=0, error=3.417178e+00
# Iter=1, error=4.889891e-04
# Iter=2, error=7.190579e-12
# t=4.310000
# Iter=0, error=3.416087e+00
# Iter=1, error=4.852201e-04
# Iter=2, error=6.885300e-12
# t=4.320000
# Iter=0, error=3.415000e+00
# Iter=1, error=4.814761e-04
# Iter=2, error=7.220634e-12
# t=4.330000
# Iter=0, error=3.413917e+00
# Iter=1, error=4.777569e-04
# Iter=2, error=6.892777e-12
# t=4.340000
# Iter=0, error=3.412837e+00
# Iter=1, error=4.740624e-04
# Iter=2, error=7.065124e-12
# t=4.350000
# Iter=0, error=3.411762e+00
# Iter=1, error=4.703925e-04
# Iter=2, error=6.515334e-12
# t=4.360000
# Iter=0, error=3.410691e+00
# Iter=1, error=4.667472e-04
# Iter=2, error=6.323796e-12
# t=4.370000
# Iter=0, error=3.409623e+00
# Iter=1, error=4.631261e-04
# Iter=2, error=6.707990e-12
# t=4.380000
# Iter=0, error=3.408560e+00
# Iter=1, error=4.595294e-04
# Iter=2, error=6.400141e-12
# t=4.390000
# Iter=0, error=3.407500e+00
# Iter=1, error=4.559567e-04
# Iter=2, error=6.224595e-12
# t=4.400000
# Iter=0, error=3.406445e+00
# Iter=1, error=4.524081e-04
# Iter=2, error=6.129469e-12
# t=4.410000
# Iter=0, error=3.405393e+00
# Iter=1, error=4.488833e-04
# Iter=2, error=6.393510e-12
# t=4.420000
# Iter=0, error=3.404345e+00
# Iter=1, error=4.453824e-04
# Iter=2, error=6.016005e-12
# t=4.430000
# Iter=0, error=3.403301e+00
# Iter=1, error=4.419050e-04
# Iter=2, error=6.256931e-12
# t=4.440000
# Iter=0, error=3.402261e+00
# Iter=1, error=4.384512e-04
# Iter=2, error=5.898469e-12
# t=4.450000
# Iter=0, error=3.401225e+00
# Iter=1, error=4.350209e-04
# Iter=2, error=5.847466e-12
# t=4.460000
# Iter=0, error=3.400193e+00
# Iter=1, error=4.316138e-04
# Iter=2, error=5.435086e-12
# t=4.470000
# Iter=0, error=3.399164e+00
# Iter=1, error=4.282299e-04
# Iter=2, error=5.115238e-12
# t=4.480000
# Iter=0, error=3.398139e+00
# Iter=1, error=4.248691e-04
# Iter=2, error=5.111099e-12
# t=4.490000
# Iter=0, error=3.397119e+00
# Iter=1, error=4.215312e-04
# Iter=2, error=5.644885e-12
# t=4.500000
# Iter=0, error=3.396102e+00
# Iter=1, error=4.182161e-04
# Iter=2, error=5.613777e-12
# t=4.510000
# Iter=0, error=3.395089e+00
# Iter=1, error=4.149238e-04
# Iter=2, error=5.478319e-12
# t=4.520000
# Iter=0, error=3.394079e+00
# Iter=1, error=4.116540e-04
# Iter=2, error=5.435293e-12
# t=4.530000
# Iter=0, error=3.393074e+00
# Iter=1, error=4.084067e-04
# Iter=2, error=5.118684e-12
# t=4.540000
# Iter=0, error=3.392072e+00
# Iter=1, error=4.051818e-04
# Iter=2, error=5.374803e-12
# t=4.550000
# Iter=0, error=3.391074e+00
# Iter=1, error=4.019791e-04
# Iter=2, error=5.089743e-12
# t=4.560000
# Iter=0, error=3.390080e+00
# Iter=1, error=3.987986e-04
# Iter=2, error=5.239569e-12
# t=4.570000
# Iter=0, error=3.389090e+00
# Iter=1, error=3.956400e-04
# Iter=2, error=4.627600e-12
# t=4.580000
# Iter=0, error=3.388103e+00
# Iter=1, error=3.925034e-04
# Iter=2, error=4.274256e-12
# t=4.590000
# Iter=0, error=3.387120e+00
# Iter=1, error=3.893885e-04
# Iter=2, error=4.593960e-12
# t=4.600000
# Iter=0, error=3.386141e+00
# Iter=1, error=3.862953e-04
# Iter=2, error=4.808230e-12
# t=4.610000
# Iter=0, error=3.385166e+00
# Iter=1, error=3.832237e-04
# Iter=2, error=4.937688e-12
# t=4.620000
# Iter=0, error=3.384194e+00
# Iter=1, error=3.801734e-04
# Iter=2, error=4.239024e-12
# t=4.630000
# Iter=0, error=3.383226e+00
# Iter=1, error=3.771445e-04
# Iter=2, error=4.613727e-12
# t=4.640000
# Iter=0, error=3.382262e+00
# Iter=1, error=3.741368e-04
# Iter=2, error=3.727019e-12
# t=4.650000
# Iter=0, error=3.381301e+00
# Iter=1, error=3.711502e-04
# Iter=2, error=3.905470e-12
# t=4.660000
# Iter=0, error=3.380345e+00
# Iter=1, error=3.681846e-04
# Iter=2, error=4.661638e-12
# t=4.670000
# Iter=0, error=3.379391e+00
# Iter=1, error=3.652398e-04
# Iter=2, error=4.577895e-12
# t=4.680000
# Iter=0, error=3.378442e+00
# Iter=1, error=3.623158e-04
# Iter=2, error=3.677372e-12
# t=4.690000
# Iter=0, error=3.377496e+00
# Iter=1, error=3.594124e-04
# Iter=2, error=4.169072e-12
# t=4.700000
# Iter=0, error=3.376554e+00
# Iter=1, error=3.565295e-04
# Iter=2, error=3.703468e-12
# t=4.710000
# Iter=0, error=3.375615e+00
# Iter=1, error=3.536671e-04
# Iter=2, error=3.535382e-12
# t=4.720000
# Iter=0, error=3.374680e+00
# Iter=1, error=3.508249e-04
# Iter=2, error=4.057062e-12
# t=4.730000
# Iter=0, error=3.373749e+00
# Iter=1, error=3.480029e-04
# Iter=2, error=4.047109e-12
# t=4.740000
# Iter=0, error=3.372821e+00
# Iter=1, error=3.452010e-04
# Iter=2, error=3.422392e-12
# t=4.750000
# Iter=0, error=3.371897e+00
# Iter=1, error=3.424191e-04
# Iter=2, error=3.807673e-12
# t=4.760000
# Iter=0, error=3.370977e+00
# Iter=1, error=3.396569e-04
# Iter=2, error=3.705400e-12
# t=4.770000
# Iter=0, error=3.370060e+00
# Iter=1, error=3.369146e-04
# Iter=2, error=3.444135e-12
# t=4.780000
# Iter=0, error=3.369147e+00
# Iter=1, error=3.341918e-04
# Iter=2, error=4.211942e-12
# t=4.790000
# Iter=0, error=3.368237e+00
# Iter=1, error=3.314886e-04
# Iter=2, error=3.178036e-12
# t=4.800000
# Iter=0, error=3.367331e+00
# Iter=1, error=3.288048e-04
# Iter=2, error=3.435824e-12
# t=4.810000
# Iter=0, error=3.366428e+00
# Iter=1, error=3.261403e-04
# Iter=2, error=3.821491e-12
# t=4.820000
# Iter=0, error=3.365529e+00
# Iter=1, error=3.234949e-04
# Iter=2, error=3.162096e-12
# t=4.830000
# Iter=0, error=3.364634e+00
# Iter=1, error=3.208687e-04
# Iter=2, error=3.551931e-12
# t=4.840000
# Iter=0, error=3.363742e+00
# Iter=1, error=3.182613e-04
# Iter=2, error=3.049751e-12
# t=4.850000
# Iter=0, error=3.362853e+00
# Iter=1, error=3.156729e-04
# Iter=2, error=2.866183e-12
# t=4.860000
# Iter=0, error=3.361968e+00
# Iter=1, error=3.131032e-04
# Iter=2, error=2.988242e-12
# t=4.870000
# Iter=0, error=3.361087e+00
# Iter=1, error=3.105521e-04
# Iter=2, error=2.951808e-12
# t=4.880000
# Iter=0, error=3.360209e+00
# Iter=1, error=3.080196e-04
# Iter=2, error=2.658657e-12
# t=4.890000
# Iter=0, error=3.359334e+00
# Iter=1, error=3.055055e-04
# Iter=2, error=3.128371e-12
# t=4.900000
# Iter=0, error=3.358463e+00
# Iter=1, error=3.030097e-04
# Iter=2, error=2.466200e-12
# t=4.910000
# Iter=0, error=3.357595e+00
# Iter=1, error=3.005322e-04
# Iter=2, error=2.363556e-12
# t=4.920000
# Iter=0, error=3.356731e+00
# Iter=1, error=2.980727e-04
# Iter=2, error=3.192817e-12
# t=4.930000
# Iter=0, error=3.355870e+00
# Iter=1, error=2.956312e-04
# Iter=2, error=2.605869e-12
# t=4.940000
# Iter=0, error=3.355013e+00
# Iter=1, error=2.932076e-04
# Iter=2, error=2.671460e-12
# t=4.950000
# Iter=0, error=3.354159e+00
# Iter=1, error=2.908018e-04
# Iter=2, error=2.520063e-12
# t=4.960000
# Iter=0, error=3.353308e+00
# Iter=1, error=2.884137e-04
# Iter=2, error=2.716723e-12
# t=4.970000
# Iter=0, error=3.352461e+00
# Iter=1, error=2.860431e-04
# Iter=2, error=2.869542e-12
# t=4.980000
# Iter=0, error=3.351618e+00
# Iter=1, error=2.836900e-04
# Iter=2, error=2.273759e-12
# t=4.990000
# Iter=0, error=3.350777e+00
# Iter=1, error=2.813543e-04
# Iter=2, error=2.273263e-12
# t=5.000000
# Iter=0, error=3.349940e+00
# Iter=1, error=2.790359e-04
# Iter=2, error=2.238584e-12
# t=5.010000
# Iter=0, error=3.349107e+00
# Iter=1, error=2.767346e-04
# Iter=2, error=2.507829e-12
# t=5.020000
# Iter=0, error=3.348276e+00
# Iter=1, error=2.744503e-04
# Iter=2, error=2.127208e-12
# t=5.030000
# Iter=0, error=3.347449e+00
# Iter=1, error=2.721830e-04
# Iter=2, error=2.171945e-12
# t=5.040000
# Iter=0, error=3.346626e+00
# Iter=1, error=2.699326e-04
# Iter=2, error=2.189064e-12
# t=5.050000
# Iter=0, error=3.345806e+00
# Iter=1, error=2.676989e-04
# Iter=2, error=2.101260e-12
# t=5.060000
# Iter=0, error=3.344989e+00
# Iter=1, error=2.654818e-04
# Iter=2, error=2.055017e-12
# t=5.070000
# Iter=0, error=3.344175e+00
# Iter=1, error=2.632813e-04
# Iter=2, error=2.039512e-12
# t=5.080000
# Iter=0, error=3.343364e+00
# Iter=1, error=2.610972e-04
# Iter=2, error=2.046259e-12
# t=5.090000
# Iter=0, error=3.342557e+00
# Iter=1, error=2.589294e-04
# Iter=2, error=2.279659e-12
# t=5.100000
# Iter=0, error=3.341754e+00
# Iter=1, error=2.567779e-04
# Iter=2, error=1.790126e-12
# t=5.110000
# Iter=0, error=3.340953e+00
# Iter=1, error=2.546426e-04
# Iter=2, error=1.766092e-12
# t=5.120000
# Iter=0, error=3.340156e+00
# Iter=1, error=2.525232e-04
# Iter=2, error=1.736038e-12
# t=5.130000
# Iter=0, error=3.339362e+00
# Iter=1, error=2.504199e-04
# Iter=2, error=2.266252e-12
# t=5.140000
# Iter=0, error=3.338571e+00
# Iter=1, error=2.483323e-04
# Iter=2, error=1.888241e-12
# t=5.150000
# Iter=0, error=3.337783e+00
# Iter=1, error=2.462605e-04
# Iter=2, error=1.795877e-12
# t=5.160000
# Iter=0, error=3.336999e+00
# Iter=1, error=2.442043e-04
# Iter=2, error=1.760393e-12
# t=5.170000
# Iter=0, error=3.336217e+00
# Iter=1, error=2.421637e-04
# Iter=2, error=1.564892e-12
# t=5.180000
# Iter=0, error=3.335439e+00
# Iter=1, error=2.401385e-04
# Iter=2, error=1.849199e-12
# t=5.190000
# Iter=0, error=3.334665e+00
# Iter=1, error=2.381287e-04
# Iter=2, error=1.802733e-12
# t=5.200000
# Iter=0, error=3.333893e+00
# Iter=1, error=2.361342e-04
# Iter=2, error=1.477779e-12
# t=5.210000
# Iter=0, error=3.333124e+00
# Iter=1, error=2.341547e-04
# ...
# t=7.530000
# Iter=0, error=3.221108e+00
# Iter=1, error=2.891943e-05
# t=7.540000
# Iter=0, error=3.220837e+00
# Iter=1, error=2.864718e-05
# t=7.550000
# Iter=0, error=3.220567e+00
# Iter=1, error=2.837741e-05
# t=7.560000
# Iter=0, error=3.220299e+00
# Iter=1, error=2.811011e-05
# t=7.570000
# Iter=0, error=3.220032e+00
# Iter=1, error=2.784525e-05
# t=7.580000
# Iter=0, error=3.219766e+00
# Iter=1, error=2.758282e-05
# t=7.590000
# Iter=0, error=3.219501e+00
# Iter=1, error=2.732278e-05
# t=7.600000
# Iter=0, error=3.219238e+00
# Iter=1, error=2.706513e-05
# t=7.610000
# Iter=0, error=3.218975e+00
# Iter=1, error=2.680983e-05
# t=7.620000
# Iter=0, error=3.218714e+00
# Iter=1, error=2.655688e-05
# t=7.630000
# Iter=0, error=3.218455e+00
# Iter=1, error=2.630624e-05
# t=7.640000
# Iter=0, error=3.218196e+00
# Iter=1, error=2.605790e-05
# t=7.650000
# Iter=0, error=3.217939e+00
# Iter=1, error=2.581183e-05
# t=7.660000
# Iter=0, error=3.217683e+00
# Iter=1, error=2.556803e-05
# t=7.670000
# Iter=0, error=3.217428e+00
# Iter=1, error=2.532646e-05
# t=7.680000
# Iter=0, error=3.217174e+00
# Iter=1, error=2.508711e-05
# t=7.690000
# Iter=0, error=3.216922e+00
# Iter=1, error=2.484997e-05
# t=7.700000
# Iter=0, error=3.216670e+00
# Iter=1, error=2.461500e-05
# t=7.710000
# Iter=0, error=3.216420e+00
# Iter=1, error=2.438219e-05
# t=7.720000
# Iter=0, error=3.216172e+00
# Iter=1, error=2.415152e-05
# t=7.730000
# Iter=0, error=3.215924e+00
# Iter=1, error=2.392297e-05
# t=7.740000
# Iter=0, error=3.215677e+00
# Iter=1, error=2.369653e-05
# t=7.750000
# Iter=0, error=3.215432e+00
# Iter=1, error=2.347218e-05
# t=7.760000
# Iter=0, error=3.215188e+00
# Iter=1, error=2.324989e-05
# t=7.770000
# Iter=0, error=3.214945e+00
# Iter=1, error=2.302965e-05
# t=7.780000
# Iter=0, error=3.214703e+00
# Iter=1, error=2.281144e-05
# t=7.790000
# Iter=0, error=3.214462e+00
# Iter=1, error=2.259524e-05
# t=7.800000
# Iter=0, error=3.214222e+00
# Iter=1, error=2.238104e-05
# t=7.810000
# Iter=0, error=3.213984e+00
# Iter=1, error=2.216882e-05
# t=7.820000
# Iter=0, error=3.213747e+00
# Iter=1, error=2.195855e-05
# t=7.830000
# Iter=0, error=3.213510e+00
# Iter=1, error=2.175023e-05
# t=7.840000
# Iter=0, error=3.213275e+00
# Iter=1, error=2.154384e-05
# t=7.850000
# Iter=0, error=3.213041e+00
# Iter=1, error=2.133935e-05
# t=7.860000
# Iter=0, error=3.212809e+00
# Iter=1, error=2.113675e-05
# t=7.870000
# Iter=0, error=3.212577e+00
# Iter=1, error=2.093603e-05
# t=7.880000
# Iter=0, error=3.212346e+00
# Iter=1, error=2.073716e-05
# t=7.890000
# Iter=0, error=3.212117e+00
# Iter=1, error=2.054014e-05
# t=7.900000
# Iter=0, error=3.211888e+00
# Iter=1, error=2.034494e-05
# t=7.910000
# Iter=0, error=3.211661e+00
# Iter=1, error=2.015155e-05
# t=7.920000
# Iter=0, error=3.211435e+00
# Iter=1, error=1.995996e-05
# t=7.930000
# Iter=0, error=3.211209e+00
# Iter=1, error=1.977014e-05
# t=7.940000
# Iter=0, error=3.210985e+00
# Iter=1, error=1.958208e-05
# t=7.950000
# Iter=0, error=3.210762e+00
# Iter=1, error=1.939576e-05
# t=7.960000
# Iter=0, error=3.210540e+00
# Iter=1, error=1.921118e-05
# t=7.970000
# Iter=0, error=3.210319e+00
# Iter=1, error=1.902830e-05
# t=7.980000
# Iter=0, error=3.210100e+00
# Iter=1, error=1.884713e-05
# t=7.990000
# Iter=0, error=3.209881e+00
# Iter=1, error=1.866764e-05
# t=8.000000
# Iter=0, error=3.209663e+00
# Iter=1, error=1.848982e-05
# t=8.010000
# Iter=0, error=3.209446e+00
# Iter=1, error=1.831366e-05
# t=8.020000
# Iter=0, error=3.209230e+00
# Iter=1, error=1.813913e-05
# t=8.030000
# Iter=0, error=3.209016e+00
# Iter=1, error=1.796623e-05
# t=8.040000
# Iter=0, error=3.208802e+00
# Iter=1, error=1.779493e-05
# t=8.050000
# Iter=0, error=3.208590e+00
# Iter=1, error=1.762523e-05
# t=8.060000
# Iter=0, error=3.208378e+00
# Iter=1, error=1.745711e-05
# t=8.070000
# Iter=0, error=3.208167e+00
# Iter=1, error=1.729056e-05
# t=8.080000
# Iter=0, error=3.207958e+00
# Iter=1, error=1.712556e-05
# t=8.090000
# Iter=0, error=3.207749e+00
# Iter=1, error=1.696210e-05
# t=8.100000
# Iter=0, error=3.207542e+00
# Iter=1, error=1.680017e-05
# t=8.110000
# Iter=0, error=3.207335e+00
# Iter=1, error=1.663974e-05
# t=8.120000
# Iter=0, error=3.207129e+00
# Iter=1, error=1.648081e-05
# t=8.130000
# Iter=0, error=3.206925e+00
# Iter=1, error=1.632337e-05
# t=8.140000
# Iter=0, error=3.206721e+00
# Iter=1, error=1.616740e-05
# t=8.150000
# Iter=0, error=3.206518e+00
# Iter=1, error=1.601288e-05
# t=8.160000
# Iter=0, error=3.206317e+00
# Iter=1, error=1.585981e-05
# t=8.170000
# Iter=0, error=3.206116e+00
# Iter=1, error=1.570817e-05
# t=8.180000
# Iter=0, error=3.205916e+00
# Iter=1, error=1.555795e-05
# t=8.190000
# Iter=0, error=3.205717e+00
# Iter=1, error=1.540913e-05
# t=8.200000
# Iter=0, error=3.205520e+00
# Iter=1, error=1.526170e-05
# t=8.210000
# Iter=0, error=3.205323e+00
# Iter=1, error=1.511566e-05
# t=8.220000
# Iter=0, error=3.205127e+00
# Iter=1, error=1.497098e-05
# t=8.230000
# Iter=0, error=3.204932e+00
# Iter=1, error=1.482766e-05
# t=8.240000
# Iter=0, error=3.204738e+00
# Iter=1, error=1.468568e-05
# t=8.250000
# Iter=0, error=3.204545e+00
# Iter=1, error=1.454504e-05
# t=8.260000
# Iter=0, error=3.204352e+00
# Iter=1, error=1.440571e-05
# t=8.270000
# Iter=0, error=3.204161e+00
# Iter=1, error=1.426768e-05
# t=8.280000
# Iter=0, error=3.203971e+00
# Iter=1, error=1.413096e-05
# t=8.290000
# Iter=0, error=3.203781e+00
# Iter=1, error=1.399551e-05
# t=8.300000
# Iter=0, error=3.203593e+00
# Iter=1, error=1.386134e-05
# t=8.310000
# Iter=0, error=3.203405e+00
# Iter=1, error=1.372843e-05
# t=8.320000
# Iter=0, error=3.203218e+00
# Iter=1, error=1.359676e-05
# t=8.330000
# Iter=0, error=3.203032e+00
# Iter=1, error=1.346634e-05
# t=8.340000
# Iter=0, error=3.202847e+00
# Iter=1, error=1.333714e-05
# t=8.350000
# Iter=0, error=3.202663e+00
# Iter=1, error=1.320915e-05
# t=8.360000
# Iter=0, error=3.202480e+00
# Iter=1, error=1.308237e-05
# t=8.370000
# Iter=0, error=3.202298e+00
# Iter=1, error=1.295678e-05
# t=8.380000
# Iter=0, error=3.202116e+00
# Iter=1, error=1.283237e-05
# t=8.390000
# Iter=0, error=3.201936e+00
# Iter=1, error=1.270913e-05
# t=8.400000
# Iter=0, error=3.201756e+00
# Iter=1, error=1.258705e-05
# t=8.410000
# Iter=0, error=3.201577e+00
# Iter=1, error=1.246612e-05
# t=8.420000
# Iter=0, error=3.201399e+00
# Iter=1, error=1.234634e-05
# t=8.430000
# Iter=0, error=3.201222e+00
# Iter=1, error=1.222768e-05
# t=8.440000
# Iter=0, error=3.201046e+00
# Iter=1, error=1.211014e-05
# t=8.450000
# Iter=0, error=3.200871e+00
# Iter=1, error=1.199370e-05
# t=8.460000
# Iter=0, error=3.200696e+00
# Iter=1, error=1.187837e-05
# t=8.470000
# Iter=0, error=3.200522e+00
# Iter=1, error=1.176412e-05
# t=8.480000
# Iter=0, error=3.200350e+00
# Iter=1, error=1.165096e-05
# t=8.490000
# Iter=0, error=3.200178e+00
# Iter=1, error=1.153885e-05
# t=8.500000
# Iter=0, error=3.200006e+00
# Iter=1, error=1.142781e-05
# t=8.510000
# Iter=0, error=3.199836e+00
# Iter=1, error=1.131782e-05
# t=8.520000
# Iter=0, error=3.199666e+00
# Iter=1, error=1.120887e-05
# t=8.530000
# Iter=0, error=3.199498e+00
# Iter=1, error=1.110094e-05
# t=8.540000
# Iter=0, error=3.199330e+00
# Iter=1, error=1.099404e-05
# t=8.550000
# Iter=0, error=3.199163e+00
# Iter=1, error=1.088815e-05
# t=8.560000
# Iter=0, error=3.198996e+00
# Iter=1, error=1.078326e-05
# t=8.570000
# Iter=0, error=3.198831e+00
# Iter=1, error=1.067936e-05
# t=8.580000
# Iter=0, error=3.198666e+00
# Iter=1, error=1.057644e-05
# t=8.590000
# Iter=0, error=3.198502e+00
# Iter=1, error=1.047450e-05
# t=8.600000
# Iter=0, error=3.198339e+00
# Iter=1, error=1.037352e-05
# t=8.610000
# Iter=0, error=3.198177e+00
# Iter=1, error=1.027350e-05
# t=8.620000
# Iter=0, error=3.198015e+00
# Iter=1, error=1.017443e-05
# t=8.630000
# Iter=0, error=3.197855e+00
# Iter=1, error=1.007629e-05
# t=8.640000
# Iter=0, error=3.197695e+00
# Iter=1, error=9.979087e-06
# t=8.650000
# Iter=0, error=3.197535e+00
# Iter=1, error=9.882804e-06
# t=8.660000
# Iter=0, error=3.197377e+00
# Iter=1, error=9.787435e-06
# t=8.670000
# Iter=0, error=3.197219e+00
# Iter=1, error=9.692967e-06
# t=8.680000
# Iter=0, error=3.197062e+00
# Iter=1, error=9.599399e-06
# t=8.690000
# Iter=0, error=3.196906e+00
# Iter=1, error=9.506718e-06
# t=8.700000
# Iter=0, error=3.196751e+00
# Iter=1, error=9.414917e-06
# t=8.710000
# Iter=0, error=3.196596e+00
# Iter=1, error=9.323986e-06
# t=8.720000
# Iter=0, error=3.196442e+00
# Iter=1, error=9.233919e-06
# t=8.730000
# Iter=0, error=3.196289e+00
# Iter=1, error=9.144708e-06
# t=8.740000
# Iter=0, error=3.196137e+00
# Iter=1, error=9.056345e-06
# t=8.750000
# Iter=0, error=3.195985e+00
# Iter=1, error=8.968821e-06
# t=8.760000
# Iter=0, error=3.195834e+00
# Iter=1, error=8.882129e-06
# t=8.770000
# Iter=0, error=3.195684e+00
# Iter=1, error=8.796263e-06
# t=8.780000
# Iter=0, error=3.195535e+00
# Iter=1, error=8.711211e-06
# t=8.790000
# Iter=0, error=3.195386e+00
# Iter=1, error=8.626970e-06
# t=8.800000
# Iter=0, error=3.195238e+00
# Iter=1, error=8.543531e-06
# t=8.810000
# Iter=0, error=3.195091e+00
# Iter=1, error=8.460885e-06
# t=8.820000
# Iter=0, error=3.194944e+00
# Iter=1, error=8.379025e-06
# t=8.830000
# Iter=0, error=3.194798e+00
# Iter=1, error=8.297945e-06
# t=8.840000
# Iter=0, error=3.194653e+00
# Iter=1, error=8.217639e-06
# t=8.850000
# Iter=0, error=3.194508e+00
# Iter=1, error=8.138095e-06
# t=8.860000
# Iter=0, error=3.194365e+00
# Iter=1, error=8.059311e-06
# t=8.870000
# Iter=0, error=3.194222e+00
# Iter=1, error=7.981278e-06
# t=8.880000
# Iter=0, error=3.194079e+00
# Iter=1, error=7.903989e-06
# t=8.890000
# Iter=0, error=3.193938e+00
# Iter=1, error=7.827434e-06
# t=8.900000
# Iter=0, error=3.193797e+00
# Iter=1, error=7.751613e-06
# t=8.910000
# Iter=0, error=3.193656e+00
# Iter=1, error=7.676513e-06
# t=8.920000
# Iter=0, error=3.193517e+00
# Iter=1, error=7.602129e-06
# t=8.930000
# Iter=0, error=3.193378e+00
# Iter=1, error=7.528457e-06
# t=8.940000
# Iter=0, error=3.193240e+00
# Iter=1, error=7.455487e-06
# t=8.950000
# Iter=0, error=3.193102e+00
# Iter=1, error=7.383214e-06
# t=8.960000
# Iter=0, error=3.192965e+00
# Iter=1, error=7.311630e-06
# t=8.970000
# Iter=0, error=3.192829e+00
# Iter=1, error=7.240732e-06
# t=8.980000
# Iter=0, error=3.192693e+00
# Iter=1, error=7.170509e-06
# t=8.990000
# Iter=0, error=3.192558e+00
# Iter=1, error=7.100960e-06
# t=9.000000
# Iter=0, error=3.192424e+00
# Iter=1, error=7.032074e-06
# t=9.010000
# Iter=0, error=3.192290e+00
# Iter=1, error=6.963847e-06
# t=9.020000
# Iter=0, error=3.192157e+00
# Iter=1, error=6.896271e-06
# t=9.030000
# Iter=0, error=3.192025e+00
# Iter=1, error=6.829344e-06
# t=9.040000
# Iter=0, error=3.191893e+00
# Iter=1, error=6.763055e-06
# t=9.050000
# Iter=0, error=3.191762e+00
# Iter=1, error=6.697400e-06
# t=9.060000
# Iter=0, error=3.191632e+00
# Iter=1, error=6.632376e-06
# t=9.070000
# Iter=0, error=3.191502e+00
# Iter=1, error=6.567971e-06
# t=9.080000
# Iter=0, error=3.191373e+00
# Iter=1, error=6.504186e-06
# t=9.090000
# Iter=0, error=3.191244e+00
# Iter=1, error=6.441010e-06
# t=9.100000
# Iter=0, error=3.191117e+00
# Iter=1, error=6.378440e-06
# t=9.110000
# Iter=0, error=3.190989e+00
# Iter=1, error=6.316469e-06
# t=9.120000
# Iter=0, error=3.190863e+00
# Iter=1, error=6.255092e-06
# t=9.130000
# Iter=0, error=3.190737e+00
# Iter=1, error=6.194302e-06
# t=9.140000
# Iter=0, error=3.190611e+00
# Iter=1, error=6.134098e-06
# t=9.150000
# Iter=0, error=3.190486e+00
# Iter=1, error=6.074468e-06
# t=9.160000
# Iter=0, error=3.190362e+00
# Iter=1, error=6.015411e-06
# t=9.170000
# Iter=0, error=3.190239e+00
# Iter=1, error=5.956920e-06
# t=9.180000
# Iter=0, error=3.190116e+00
# Iter=1, error=5.898990e-06
# t=9.190000
# Iter=0, error=3.189993e+00
# Iter=1, error=5.841618e-06
# t=9.200000
# Iter=0, error=3.189872e+00
# Iter=1, error=5.784794e-06
# t=9.210000
# Iter=0, error=3.189750e+00
# Iter=1, error=5.728517e-06
# t=9.220000
# Iter=0, error=3.189630e+00
# Iter=1, error=5.672780e-06
# t=9.230000
# Iter=0, error=3.189510e+00
# Iter=1, error=5.617578e-06
# t=9.240000
# Iter=0, error=3.189390e+00
# Iter=1, error=5.562907e-06
# t=9.250000
# Iter=0, error=3.189271e+00
# Iter=1, error=5.508761e-06
# t=9.260000
# Iter=0, error=3.189153e+00
# Iter=1, error=5.455134e-06
# t=9.270000
# Iter=0, error=3.189036e+00
# Iter=1, error=5.402024e-06
# t=9.280000
# Iter=0, error=3.188918e+00
# Iter=1, error=5.349424e-06
# t=9.290000
# Iter=0, error=3.188802e+00
# Iter=1, error=5.297328e-06
# t=9.300000
# Iter=0, error=3.188686e+00
# Iter=1, error=5.245736e-06
# t=9.310000
# Iter=0, error=3.188571e+00
# Iter=1, error=5.194639e-06
# t=9.320000
# Iter=0, error=3.188456e+00
# Iter=1, error=5.144033e-06
# t=9.330000
# Iter=0, error=3.188341e+00
# Iter=1, error=5.093913e-06
# t=9.340000
# Iter=0, error=3.188228e+00
# Iter=1, error=5.044278e-06
# t=9.350000
# Iter=0, error=3.188115e+00
# Iter=1, error=4.995119e-06
# t=9.360000
# Iter=0, error=3.188002e+00
# Iter=1, error=4.946434e-06
# t=9.370000
# Iter=0, error=3.187890e+00
# Iter=1, error=4.898218e-06
# t=9.380000
# Iter=0, error=3.187778e+00
# Iter=1, error=4.850465e-06
# t=9.390000
# Iter=0, error=3.187667e+00
# Iter=1, error=4.803172e-06
# t=9.400000
# Iter=0, error=3.187557e+00
# Iter=1, error=4.756337e-06
# t=9.410000
# Iter=0, error=3.187447e+00
# Iter=1, error=4.709951e-06
# t=9.420000
# Iter=0, error=3.187338e+00
# Iter=1, error=4.664012e-06
# t=9.430000
# Iter=0, error=3.187229e+00
# Iter=1, error=4.618516e-06
# t=9.440000
# Iter=0, error=3.187121e+00
# Iter=1, error=4.573460e-06
# t=9.450000
# Iter=0, error=3.187013e+00
# Iter=1, error=4.528837e-06
# t=9.460000
# Iter=0, error=3.186906e+00
# Iter=1, error=4.484646e-06
# t=9.470000
# Iter=0, error=3.186799e+00
# Iter=1, error=4.440879e-06
# t=9.480000
# Iter=0, error=3.186693e+00
# Iter=1, error=4.397536e-06
# t=9.490000
# Iter=0, error=3.186587e+00
# Iter=1, error=4.354610e-06
# t=9.500000
# Iter=0, error=3.186482e+00
# Iter=1, error=4.312099e-06
# t=9.510000
# Iter=0, error=3.186377e+00
# Iter=1, error=4.269998e-06
# t=9.520000
# Iter=0, error=3.186273e+00
# Iter=1, error=4.228304e-06
# t=9.530000
# Iter=0, error=3.186170e+00
# Iter=1, error=4.187010e-06
# t=9.540000
# Iter=0, error=3.186067e+00
# Iter=1, error=4.146118e-06
# t=9.550000
# Iter=0, error=3.185964e+00
# Iter=1, error=4.105620e-06
# t=9.560000
# Iter=0, error=3.185862e+00
# Iter=1, error=4.065512e-06
# t=9.570000
# Iter=0, error=3.185760e+00
# Iter=1, error=4.025794e-06
# t=9.580000
# Iter=0, error=3.185659e+00
# Iter=1, error=3.986457e-06
# t=9.590000
# Iter=0, error=3.185559e+00
# Iter=1, error=3.947502e-06
# t=9.600000
# Iter=0, error=3.185459e+00
# Iter=1, error=3.908922e-06
# t=9.610000
# Iter=0, error=3.185359e+00
# Iter=1, error=3.870718e-06
# t=9.620000
# Iter=0, error=3.185260e+00
# Iter=1, error=3.832880e-06
# t=9.630000
# Iter=0, error=3.185161e+00
# Iter=1, error=3.795410e-06
# t=9.640000
# Iter=0, error=3.185063e+00
# Iter=1, error=3.758303e-06
# t=9.650000
# Iter=0, error=3.184965e+00
# Iter=1, error=3.721552e-06
# t=9.660000
# Iter=0, error=3.184868e+00
# Iter=1, error=3.685159e-06
# t=9.670000
# Iter=0, error=3.184772e+00
# Iter=1, error=3.649118e-06
# t=9.680000
# Iter=0, error=3.184675e+00
# Iter=1, error=3.613425e-06
# t=9.690000
# Iter=0, error=3.184580e+00
# Iter=1, error=3.578079e-06
# t=9.700000
# Iter=0, error=3.184484e+00
# Iter=1, error=3.543073e-06
# t=9.710000
# Iter=0, error=3.184389e+00
# Iter=1, error=3.508407e-06
# t=9.720000
# Iter=0, error=3.184295e+00
# Iter=1, error=3.474078e-06
# t=9.730000
# Iter=0, error=3.184201e+00
# Iter=1, error=3.440080e-06
# t=9.740000
# Iter=0, error=3.184108e+00
# Iter=1, error=3.406413e-06
# t=9.750000
# Iter=0, error=3.184015e+00
# Iter=1, error=3.373071e-06
# t=9.760000
# Iter=0, error=3.183922e+00
# Iter=1, error=3.340051e-06
# t=9.770000
# Iter=0, error=3.183830e+00
# Iter=1, error=3.307351e-06
# t=9.780000
# Iter=0, error=3.183739e+00
# Iter=1, error=3.274970e-06
# t=9.790000
# Iter=0, error=3.183647e+00
# Iter=1, error=3.242901e-06
# t=9.800000
# Iter=0, error=3.183557e+00
# Iter=1, error=3.211145e-06
# t=9.810000
# Iter=0, error=3.183466e+00
# Iter=1, error=3.179695e-06
# t=9.820000
# Iter=0, error=3.183377e+00
# Iter=1, error=3.148551e-06
# t=9.830000
# Iter=0, error=3.183287e+00
# Iter=1, error=3.117710e-06
# t=9.840000
# Iter=0, error=3.183198e+00
# Iter=1, error=3.087168e-06
# t=9.850000
# Iter=0, error=3.183110e+00
# Iter=1, error=3.056920e-06
# t=9.860000
# Iter=0, error=3.183022e+00
# Iter=1, error=3.026968e-06
# t=9.870000
# Iter=0, error=3.182934e+00
# Iter=1, error=2.997305e-06
# t=9.880000
# Iter=0, error=3.182847e+00
# Iter=1, error=2.967930e-06
# t=9.890000
# Iter=0, error=3.182760e+00
# Iter=1, error=2.938843e-06
# t=9.900000
# Iter=0, error=3.182674e+00
# Iter=1, error=2.910034e-06
# t=9.910000
# Iter=0, error=3.182588e+00
# Iter=1, error=2.881508e-06
# t=9.920000
# Iter=0, error=3.182502e+00
# Iter=1, error=2.853258e-06
# t=9.930000
# Iter=0, error=3.182417e+00
# Iter=1, error=2.825284e-06
# t=9.940000
# Iter=0, error=3.182332e+00
# Iter=1, error=2.797579e-06
# t=9.950000
# Iter=0, error=3.182248e+00
# Iter=1, error=2.770145e-06
# t=9.960000
# Iter=0, error=3.182164e+00
# Iter=1, error=2.742978e-06
# t=9.970000
# Iter=0, error=3.182081e+00
# Iter=1, error=2.716073e-06
# t=9.980000
# Iter=0, error=3.181998e+00
# Iter=1, error=2.689432e-06
